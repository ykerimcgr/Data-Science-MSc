# %% [markdown]
# # Week 5: Document Similarity
#
# In some applications, it may be difficult to define the classes that we want to use in classification ahead of time.  Or, classes might be made up various subclasses (which differ in terms of the vocabulary used).  In both of these cases (and others), it might be more appropriate to think about **document similarity**.  For a new document, can we find the most similar document in our collection?
#
# ### Preliminaries

# %%
###uncomment if working on colab

#from google.colab import drive
#drive.mount('/content/drive')

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/kerimciger/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kerimciger/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     /Users/kerimciger/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
from utils import *
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kerimciger/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Now lets get a document collection.  We are going to use the Gutenberg collection of books.  We will get the tokenised content of each book and store it in a dictionary (key = the fileid of the book) for easy access.

# %%
from nltk.corpus import gutenberg

book_ids=gutenberg.fileids()
books={b:gutenberg.words(b) for b in book_ids}

# %%
books[book_ids[0]]
# Out:
# ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']', ...]

# %%
books.keys()
# Out:
# dict_keys(['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt'])

# %% [markdown]
# We now need to normalise the tokens in the documents and construct a *bag-of-words* document representation.  Combining some of the functionality we have been working over the past few weeks (which we have imported from utils.py), we could use something like this

# %%
from nltk.probability import FreqDist

book_reps={key:FreqDist(normalise(book)) for key,book in books.items()}

# %% [markdown]
# Let's have a look at the representation of first book:

# %%
print(book_reps[book_ids[0]].items())
# Out:
# dict_items([('emma', 865), ('jane', 301), ('austen', 1), ('volume', 3), ('chapter', 56), ('woodhouse', 313), ('handsome', 38), ('clever', 27), ('rich', 14), ('comfortable', 34), ('home', 130), ('happy', 125), ('disposition', 24), ('seemed', 141), ('unite', 3), ('best', 85), ('blessings', 6), ('existence', 8), ('lived', 25), ('nearly', 14), ('twenty', 30), ('one', 452), ('years', 57), ('world', 81), ('little', 359), ('distress', 19), ('vex', 1), ('youngest', 4), ('two', 178), ('daughters', 7), ('affectionate', 9), ('indulgent', 2), ('father', 207), ('consequence', 27), ('sister', 33), ('marriage', 35), ('mistress', 11), ('house', 95), ('early', 41), ('period', 18), ('mother', 72), ('died', 4), ('long', 146), ('ago', 32), ('indistinct', 1), ('remembrance', 8), ('caresses', 1), ('place', 93), ('supplied', 5), ('excellent', 34), ('woman', 131), ('governess', 9), ('fallen', 7), ('short', 70), ('affection', 50), ('sixteen', 9), ('miss', 599), ('taylor', 48), ('mr', 1153), ('family', 77), ('less', 68), ('friend', 177), ('fond', 39), ('particularly', 46), ('intimacy', 21), ('sisters', 12), ('even', 132), ('ceased', 6), ('hold', 14), ('nominal', 1), ('office', 16), ('mildness', 1), ('temper', 36), ('hardly', 71), ('allowed', 40), ('impose', 1), ('restraint', 3), ('shadow', 2), ('authority', 6), ('passed', 55), ('away', 138), ('living', 18), ('together', 81), ('mutually', 3), ('attached', 25), ('liked', 16), ('highly', 24), ('esteeming', 1), ('judgment', 29), ('directed', 6), ('chiefly', 7), ('real', 42), ('evils', 10), ('indeed', 202), ('situation', 64), ('power', 41), ('rather', 146), ('much', 486), ('way', 155), ('think', 383), ('well', 401), ('disadvantages', 1), ('threatened', 4), ('alloy', 3), ('many', 138), ('enjoyments', 3), ('danger', 31), ('however', 131), ('present', 89), ('unperceived', 2), ('means', 48), ('rank', 9), ('misfortunes', 1), ('sorrow', 4), ('came', 119), ('gentle', 16), ('shape', 5), ('disagreeable', 20), ('consciousness', 21), ('married', 45), ('loss', 23), ('first', 209), ('brought', 54), ('grief', 5), ('wedding', 17), ('day', 192), ('beloved', 9), ('sat', 37), ('mournful', 1), ('thought', 226), ('continuance', 2), ('bride', 13), ('people', 95), ('gone', 80), ('left', 68), ('dine', 15), ('prospect', 13), ('third', 5), ('cheer', 4), ('evening', 96), ('composed', 6), ('sleep', 2), ('dinner', 49), ('usual', 51), ('sit', 38), ('lost', 21), ('event', 24), ('every', 435), ('promise', 21), ('happiness', 76), ('weston', 440), ('man', 235), ('unexceptionable', 7), ('character', 43), ('easy', 28), ('fortune', 39), ('suitable', 4), ('age', 22), ('pleasant', 41), ('manners', 53), ('satisfaction', 28), ('considering', 20), ('self', 23), ('denying', 7), ('generous', 4), ('friendship', 26), ('always', 238), ('wished', 48), ('promoted', 4), ('match', 32), ('black', 5), ('morning', 111), ('work', 22), ('want', 90), ('would', 820), ('felt', 113), ('hour', 83), ('recalled', 2), ('past', 20), ('kindness', 40), ('taught', 7), ('played', 8), ('five', 42), ('old', 85), ('devoted', 5), ('powers', 14), ('attach', 5), ('amuse', 8), ('health', 39), ('nursed', 3), ('various', 6), ('illnesses', 3), ('childhood', 2), ('large', 35), ('debt', 1), ('gratitude', 29), ('owing', 3), ('intercourse', 12), ('last', 119), ('seven', 8), ('equal', 57), ('footing', 3), ('perfect', 34), ('unreserve', 6), ('soon', 224), ('followed', 29), ('isabella', 69), ('yet', 109), ('dearer', 6), ('tenderer', 1), ('recollection', 8), ('companion', 27), ('possessed', 3), ('intelligent', 4), ('informed', 5), ('useful', 21), ('knowing', 26), ('ways', 16), ('interested', 15), ('concerns', 9), ('peculiarly', 11), ('pleasure', 115), ('scheme', 23), ('could', 837), ('speak', 99), ('arose', 4), ('never', 358), ('find', 75), ('fault', 20), ('bear', 52), ('change', 61), ('true', 66), ('going', 120), ('half', 118), ('mile', 11), ('aware', 26), ('great', 264), ('must', 567), ('difference', 31), ('mrs', 699), ('advantages', 12), ('natural', 52), ('domestic', 7), ('suffering', 16) ...

# %%
book_reps[book_ids[0]]["1816"]
# Out:
# 0

# %% [markdown]
# ## Measuring Similarity
# We are going to use the cosine measure to determine how similar two books are. This can be defined in terms of the dot products of vectors:
#
# $$
# \text{sim}_{\text{cosine}}(A,B) = \frac{A \cdot B}{\sqrt{A \cdot A \times B \cdot B}}
# $$
#
# where the dot product of two vectors, \(A\) and \(B\), is defined as:
#
# $$
# A \cdot B = \sum_f \text{weight}(A,f) \times \text{weight}(B,f)
# $$
#
# and $(\text{weight}(X,f))$ tells us the value associated with feature $(f)$ in the vector representation of $(X)$.
#
# ### Exercise 1.1
# * Write a function `dot` which takes two documents ( represented as dictionaries or `FreqDist`'s ) and returns their dot product.
# * Test it out on the first two books in Gutenberg. You should get the answer 3882298!
# * Why is the number so large?

# %%
# %%timeit
def dot( docA: nltk.probability.FreqDist, docB: nltk.probability.FreqDist ) -> int:
    summ = 0
    for key, value in docA.items():
        prod = value * docB.get( key, 0 )
        summ += prod

    return summ

# %%
docA = book_reps[book_ids[0]]
docB = book_reps[book_ids[1]]

dot(docA, docB)
# Out:
# 3882298

# %% [markdown]
# ### Exercise 1.2
# * Write a function `cos_sim` which takes two documents (represented as dictionaries or `FreqDist`s) and returns their cosine similarity.
# * Your function should make 3 calls to the `dot` function you have already defined
# * If you test it out on the first two documents in the collection you should get 0.72 (to 2S.F.)

# %%
def cos_sim(docA: nltk.probability.FreqDist, docB: nltk.probability.FreqDist):
    upper = dot( docA, docB )
    lower = (dot(docA, docA) * dot(docB, docB))**0.5 
    sim = upper / lower if lower != 0 else 0
    return sim

cos_sim(docA,docB)
# Out:
# 0.7209827887675819

# %%
import math

def cos_sim(docA,docB):
    sim=dot(docA,docB)/(math.sqrt(dot(docA,docA)*dot(docB,docB)))
    return sim

cos_sim(docA,docB)
# Out:
# 0.7209827887675819

# %% [markdown]
# ### Exercise 1.3
# * Write some code that will compute the similarity of every document in a collection with every document in another collection
# * Write code to compute the average similarity of two collections
# * Compute (and display) the average similarity of the book collection to itself

# %%
import pandas as pd

def compute_all_pairs_sim( collectionA, collectionB ):
    sim_res = {}
    for keyA, docA in collectionA.items():
        sim_res[keyA] = {}
        for keyB, docB in collectionB.items():
            sim_res[keyA][keyB] = cos_sim( docA, docB )
    return sim_res

allsims = compute_all_pairs_sim(book_reps,book_reps)

allsims_df = pd.DataFrame(allsims)

allsims_df.head()
# Out:
#                        austen-emma.txt  austen-persuasion.txt  \
# austen-emma.txt               1.000000               0.720983
# austen-persuasion.txt         0.720983               1.000000
# austen-sense.txt              0.714178               0.698421
# bible-kjv.txt                 0.234961               0.229095
# blake-poems.txt               0.277624               0.272859
#
#                        austen-sense.txt  bible-kjv.txt  blake-poems.txt  \
# austen-emma.txt                0.714178       0.234961         0.277624
# austen-persuasion.txt          0.698421       0.229095         0.272859
# austen-sense.txt               1.000000       0.254851         0.283665
# bible-kjv.txt                  0.254851       1.000000         0.375129
# blake-poems.txt                0.283665       0.375129         1.000000
#
#                        bryant-stories.txt  burgess-busterbrown.txt  \
# austen-emma.txt                  0.484001                 0.344390
# austen-persuasion.txt            0.488966                 0.347673
# austen-sense.txt                 0.486361                 0.326153
# bible-kjv.txt                    0.348728                 0.139435
# blake-poems.txt                  0.465337                 0.289868
#
#                        carroll-alice.txt  chesterton-ball.txt  \
# austen-emma.txt                 0.431975             0.493510
# austen-persuasion.txt           0.415685             0.486170
# austen-sense.txt                0.439460             0.491066
# bible-kjv.txt                   0.260582             0.334730
# blake-poems.txt                 0.265321             0.324392
#
#                        chesterton-brown.txt  chesterton-thursday.txt  \
# austen-emma.txt                    0.566961                 0.469868
# austen-persuasion.txt              0.572391                 0.470311
# austen-sense.txt                   0.549179                 0.480280
# bible-kjv.txt                      0.327006                 0.311154
# blake-poems.txt                    0.368291                 0.313903
#
#                        edgeworth-parents.txt  melville-moby_dick.txt  \
# austen-emma.txt                     0.688556                0.467413
# austen-persuasion.txt               0.670928                0.505420
# austen-sense.txt                    0.672770                0.474923
# bible-kjv.txt                       0.389897                0.359606
# blake-poems.txt                     0.382288                0.374348
#
#                        milton-paradise.txt  shakespeare-caesar.txt  \
# austen-emma.txt                   0.315463                0.245423
# austen-persuasion.txt             0.331911                0.241884
# austen-sense.txt                  0.338120                0.239480
# bible-kjv.txt                     0.544221                0.371062
# blake-poems.txt                   0.529776                0.275073
#
#                        shakespeare-hamlet.txt  shakespeare-macbeth.txt  \
# austen-emma.txt                      0.268859                 0.276954
# austen-persuasion.txt                0.269344                 0.294243
# austen-sense.txt                     0.268830                 0.281037
# bible-kjv.txt                        0.418882                 0.393311
# blake-poems.txt                      0.289585                 0.321513
#
#                        whitman-leaves.txt
# austen-emma.txt                  0.420653
# austen-persuasion.txt            0.435392
# austen-sense.txt                 0.438404
# bible-kjv.txt                    0.445999
# blake-poems.txt                  0.555633

# %%
def all_pairs_sims(collectionA: dict, collectionB: dict) -> dict:
    sims={}
    print( f'Types of documents: {type(collectionA)} {type(collectionB)}' )
    for keyA,docA in collectionA.items():
        sims[keyA]={}
        for keyB,docB in collectionB.items():
            sim=cos_sim(docA,docB)
            sims[keyA][keyB]=sim
            
    return sims


allsims=all_pairs_sims(book_reps,book_reps)
print(allsims)
# Out:
# Types of documents: <class 'dict'> <class 'dict'>
# {'austen-emma.txt': {'austen-emma.txt': 1.0, 'austen-persuasion.txt': 0.7209827887675819, 'austen-sense.txt': 0.7141776265718526, 'bible-kjv.txt': 0.2349609219845515, 'blake-poems.txt': 0.2776236092963711, 'bryant-stories.txt': 0.4840013265541457, 'burgess-busterbrown.txt': 0.344389530877187, 'carroll-alice.txt': 0.4319750042697858, 'chesterton-ball.txt': 0.4935101011270622, 'chesterton-brown.txt': 0.5669614267935984, 'chesterton-thursday.txt': 0.4698682997700355, 'edgeworth-parents.txt': 0.6885556624822814, 'melville-moby_dick.txt': 0.4674131272963583, 'milton-paradise.txt': 0.3154632269322213, 'shakespeare-caesar.txt': 0.2454234304603725, 'shakespeare-hamlet.txt': 0.26885904270302036, 'shakespeare-macbeth.txt': 0.27695388261336384, 'whitman-leaves.txt': 0.42065330682321106}, 'austen-persuasion.txt': {'austen-emma.txt': 0.7209827887675819, 'austen-persuasion.txt': 1.0, 'austen-sense.txt': 0.698421056723616, 'bible-kjv.txt': 0.22909486572238824, 'blake-poems.txt': 0.2728585369785559, 'bryant-stories.txt': 0.4889655556320332, 'burgess-busterbrown.txt': 0.347673037011721, 'carroll-alice.txt': 0.41568476444219815, 'chesterton-ball.txt': 0.4861695324682726, 'chesterton-brown.txt': 0.5723906718254852, 'chesterton-thursday.txt': 0.4703108113975414, 'edgeworth-parents.txt': 0.6709280755815106, 'melville-moby_dick.txt': 0.5054200099369706, 'milton-paradise.txt': 0.3319111468754161, 'shakespeare-caesar.txt': 0.2418838661665231, 'shakespeare-hamlet.txt': 0.2693440426225194, 'shakespeare-macbeth.txt': 0.2942427907259151, 'whitman-leaves.txt': 0.435391630054623}, 'austen-sense.txt': {'austen-emma.txt': 0.7141776265718526, 'austen-persuasion.txt': 0.698421056723616, 'austen-sense.txt': 1.0, 'bible-kjv.txt': 0.25485061730334274, 'blake-poems.txt': 0.28366459672848504, 'bryant-stories.txt': 0.4863607674152473, 'burgess-busterbrown.txt': 0.32615255545073696, 'carroll-alice.txt': 0.43945971715850185, 'chesterton-ball.txt': 0.49106585557313576, 'chesterton-brown.txt': 0.5491788282227019, 'chesterton-thursday.txt': 0.4802803552133886, 'edgeworth-parents.txt': 0.6727698406958084, 'melville-moby_dick.txt': 0.47492296268483536, 'milton-paradise.txt': 0.33811954648411485, 'shakespeare-caesar.txt': 0.23947976557291523, 'shakespeare-hamlet.txt': 0.26882970777864085, 'shakespeare-macbeth.txt': 0.2810370272502472, 'whitman-leaves.txt': 0.4384040552672959}, 'bible-kjv.txt': {'austen-emma.txt': 0.2349609219845515, 'austen-persuasion.txt': 0.22909486572238824, 'austen-sense.txt': 0.25485061730334274, 'bible-kjv.txt': 1.0, 'blake-poems.txt': 0.37512850409150755, 'bryant-stories.txt': 0.3487281884303432, 'burgess-busterbrown.txt': 0.13943453435593514, 'carroll-alice.txt': 0.2605822801580707, 'chesterton-ball.txt': 0.3347297111246903, 'chesterton-brown.txt': 0.3270057265220799, 'chesterton-thursday.txt': 0.3111541637698135, 'edgeworth-parents.txt': 0.3898966176823307, 'melville-moby_dick.txt': 0.35960576538724115, 'milton-paradise.txt': 0.5442213518119406, 'shakespeare-caesar.txt': 0.3710616363746544, 'shakespeare-hamlet.txt': 0.418882217363832, 'shakespeare-macbeth.txt': 0.39331112877114294, 'whitman-leaves.txt': 0.44599921739788895}, 'blake-poems.txt': {'austen-emma.txt': 0.2776236092963711, 'austen-persuasion.txt': 0.2728585369785559, 'austen-sense.txt': 0.28366459672848504, 'bible-kjv.txt': 0.37512850409150755, 'blake-poems.txt': 1.0, 'bryant-stories.txt': 0.4653370597216538, 'burgess-busterbrown.txt': 0.28986780541463925, 'carroll-alice.txt': 0.26532123584491774, 'chesterton-ball.txt': 0.32439156887918086, 'chesterton-brown.txt': 0.36829149809449324, 'chesterton-thursday.txt': 0.31390320773015, 'edgeworth-parents.txt': 0.3822883097277848, 'melville-moby_dick.txt': 0.3743481339945486, 'milton-paradise.txt': 0.5297758507806719, 'shakespeare-caesar.txt': 0.2750732641215323, 'shakespeare-hamlet.txt': 0.28958526601790424, 'shakespeare-macbeth.txt': 0.32151347577309386, 'whitman-leaves.txt': 0.5556331824715729}, 'bryant-stories.txt': {'austen-emma.txt': 0.4840 ...

# %%
import pandas as pd

df = pd.DataFrame(allsims)
df.head()
# Out:
#                        austen-emma.txt  austen-persuasion.txt  \
# austen-emma.txt               1.000000               0.720983
# austen-persuasion.txt         0.720983               1.000000
# austen-sense.txt              0.714178               0.698421
# bible-kjv.txt                 0.234961               0.229095
# blake-poems.txt               0.277624               0.272859
#
#                        austen-sense.txt  bible-kjv.txt  blake-poems.txt  \
# austen-emma.txt                0.714178       0.234961         0.277624
# austen-persuasion.txt          0.698421       0.229095         0.272859
# austen-sense.txt               1.000000       0.254851         0.283665
# bible-kjv.txt                  0.254851       1.000000         0.375129
# blake-poems.txt                0.283665       0.375129         1.000000
#
#                        bryant-stories.txt  burgess-busterbrown.txt  \
# austen-emma.txt                  0.484001                 0.344390
# austen-persuasion.txt            0.488966                 0.347673
# austen-sense.txt                 0.486361                 0.326153
# bible-kjv.txt                    0.348728                 0.139435
# blake-poems.txt                  0.465337                 0.289868
#
#                        carroll-alice.txt  chesterton-ball.txt  \
# austen-emma.txt                 0.431975             0.493510
# austen-persuasion.txt           0.415685             0.486170
# austen-sense.txt                0.439460             0.491066
# bible-kjv.txt                   0.260582             0.334730
# blake-poems.txt                 0.265321             0.324392
#
#                        chesterton-brown.txt  chesterton-thursday.txt  \
# austen-emma.txt                    0.566961                 0.469868
# austen-persuasion.txt              0.572391                 0.470311
# austen-sense.txt                   0.549179                 0.480280
# bible-kjv.txt                      0.327006                 0.311154
# blake-poems.txt                    0.368291                 0.313903
#
#                        edgeworth-parents.txt  melville-moby_dick.txt  \
# austen-emma.txt                     0.688556                0.467413
# austen-persuasion.txt               0.670928                0.505420
# austen-sense.txt                    0.672770                0.474923
# bible-kjv.txt                       0.389897                0.359606
# blake-poems.txt                     0.382288                0.374348
#
#                        milton-paradise.txt  shakespeare-caesar.txt  \
# austen-emma.txt                   0.315463                0.245423
# austen-persuasion.txt             0.331911                0.241884
# austen-sense.txt                  0.338120                0.239480
# bible-kjv.txt                     0.544221                0.371062
# blake-poems.txt                   0.529776                0.275073
#
#                        shakespeare-hamlet.txt  shakespeare-macbeth.txt  \
# austen-emma.txt                      0.268859                 0.276954
# austen-persuasion.txt                0.269344                 0.294243
# austen-sense.txt                     0.268830                 0.281037
# bible-kjv.txt                        0.418882                 0.393311
# blake-poems.txt                      0.289585                 0.321513
#
#                        whitman-leaves.txt
# austen-emma.txt                  0.420653
# austen-persuasion.txt            0.435392
# austen-sense.txt                 0.438404
# bible-kjv.txt                    0.445999
# blake-poems.txt                  0.555633

# %%
def compute_avg_similarity( collectionA: dict, collectionB: dict, sim_results = {} ) -> float:
    if sim_results == {}:
        sim_results = compute_all_pairs_sim( collectionA, collectionB )

    sim_sum = 0
    for sim_rec in sim_results.values():
        for sim in sim_rec.values():
            sim_sum += sim

    return sim_sum / (len(collectionA) * len(collectionB))

sim = compute_avg_similarity(book_reps,book_reps,sim_results = allsims)
print( f"The average similarity of the book collection to itself is {sim:.4f}")
# Out:
# The average similarity of the book collection to itself is 0.4451

# %%
def average_similarity(collectionA,collectionB,sims={}):
    
    if sims=={}:
        sims=all_pairs_sims(collectionA,collectionB)
    totalsim=0
    n=0
    for simvals in sims.values():
        for simval in simvals.values():
            totalsim+=simval
            n+=1
    #return totalsim/(len(collectionA)*len(collectionB))
    return totalsim/n
    
sim=average_similarity(book_reps,book_reps,sims=allsims)
print("The average similarity of the book collection to itself is {:.4f}".format(sim))
# Out:
# The average similarity of the book collection to itself is 0.4451

# %% [markdown]
# ## Beyond Frequency
# The frequency of a word in a document does not make a very good weight because some words occur very frequently in all documents. If two rare words occur in both of our pair of documents, that should add more to their perceived similarity than if two common words occur in both of our pair of documents.
#
# ### TFIDF
# A commonly used weight is TF-IDF, which stands for **term frequency, inverse document frequency**:
#
# $$
# \text{tfidf}(D_i, f) = tf(D_i, f) \times \text{idf}(D_i, f)
# $$
#
# where $(tf(D_i, f))$ is simply the frequency of feature $(f)$ in document $(D_i)$, and:
#
# $$
# \text{idf}(D_i, f) = \log \frac{N}{df(f)}
# $$
#
# where $(N)$ is the total number of documents and $(\text{df}(f))$ is the number of documents containing $(f)$:
#
# $$
# df(f) = |\{i \mid \text{freq}(D_i, f) > 0\}|
# $$
#
# The code below will take a list of documents (represented as dictionaries) and compute the document frequency for each feature. Test it out on the collection of books.

# %%
def doc_freq(doclist):
    df={}
    for doc in doclist:
        for feat in doc.keys():
            df[feat]=df.get(feat,0)+1
            
    return df

# %%
doc_freq(book_reps.values())
# Out:
# {'emma': 2,
#  'jane': 3,
#  'austen': 3,
#  'volume': 11,
#  'chapter': 8,
#  'woodhouse': 1,
#  'handsome': 11,
#  'clever': 10,
#  'rich': 17,
#  'comfortable': 13,
#  'home': 18,
#  'happy': 18,
#  'disposition': 10,
#  'seemed': 15,
#  'unite': 6,
#  'best': 18,
#  'blessings': 7,
#  'existence': 10,
#  'lived': 14,
#  'nearly': 13,
#  'twenty': 16,
#  'one': 18,
#  'years': 15,
#  'world': 18,
#  'little': 18,
#  'distress': 12,
#  'vex': 7,
#  'youngest': 10,
#  'two': 18,
#  'daughters': 11,
#  'affectionate': 8,
#  'indulgent': 6,
#  'father': 17,
#  'consequence': 13,
#  'sister': 14,
#  'marriage': 12,
#  'mistress': 10,
#  'house': 18,
#  'early': 14,
#  'period': 8,
#  'mother': 17,
#  'died': 15,
#  'long': 18,
#  'ago': 14,
#  'indistinct': 3,
#  'remembrance': 10,
#  'caresses': 5,
#  'place': 18,
#  'supplied': 8,
#  'excellent': 13,
#  'woman': 17,
#  'governess': 3,
#  'fallen': 15,
#  'short': 16,
#  'affection': 12,
#  'sixteen': 7,
#  'miss': 13,
#  'taylor': 3,
#  'mr': 10,
#  'family': 13,
#  'less': 14,
#  'friend': 18,
#  'fond': 14,
#  'particularly': 9,
#  'intimacy': 6,
#  'sisters': 12,
#  'even': 14,
#  'ceased': 10,
#  'hold': 17,
#  'nominal': 3,
#  'office': 15,
#  'mildness': 8,
#  'temper': 15,
#  'hardly': 16,
#  'allowed': 11,
#  'impose': 6,
#  'restraint': 10,
#  'shadow': 15,
#  'authority': 12,
#  'passed': 13,
#  'away': 18,
#  'living': 13,
#  'together': 17,
#  'mutually': 4,
#  'attached': 9,
#  'liked': 12,
#  'highly': 13,
#  'esteeming': 3,
#  'judgment': 6,
#  'directed': 10,
#  'chiefly': 9,
#  'real': 13,
#  'evils': 7,
#  'indeed': 18,
#  'situation': 10,
#  'power': 16,
#  'rather': 17,
#  'much': 17,
#  'way': 18,
#  'think': 18,
#  'well': 18,
#  'disadvantages': 3,
#  'threatened': 8,
#  'alloy': 3,
#  'many': 18,
#  'enjoyments': 6,
#  'danger': 16,
#  'however': 13,
#  'present': 16,
#  'unperceived': 3,
#  'means': 13,
#  'rank': 13,
#  'misfortunes': 5,
#  'sorrow': 17,
#  'came': 18,
#  'gentle': 16,
#  'shape': 16,
#  'disagreeable': 5,
#  'consciousness': 6,
#  'married': 11,
#  'loss': 12,
#  'first': 17,
#  'brought': 18,
#  'grief': 12,
#  'wedding': 10,
#  'day': 18,
#  'beloved': 10,
#  'sat': 15,
#  'mournful': 6,
#  'thought': 18,
#  'continuance': 4,
#  'bride': 7,
#  'people': 17,
#  'gone': 18,
#  'left': 18,
#  'dine': 7,
#  'prospect': 8,
#  'third': 15,
#  'cheer': 9,
#  'evening': 14,
#  'composed': 9,
#  'sleep': 16,
#  'dinner': 15,
#  'usual': 12,
#  'sit': 18,
#  'lost': 18,
#  'event': 10,
#  'every': 15,
#  'promise': 15,
#  'happiness': 11,
#  'weston': 1,
#  'man': 18,
#  'unexceptionable': 2,
#  'character': 12,
#  'easy': 14,
#  'fortune': 12,
#  'suitable': 7,
#  'age': 18,
#  'pleasant': 17,
#  'manners': 12,
#  'satisfaction': 12,
#  'considering': 9,
#  'self': 15,
#  'denying': 8,
#  'generous': 10,
#  'friendship': 14,
#  'always': 15,
#  'wished': 10,
#  'promoted': 4,
#  'match': 8,
#  'black': 15,
#  'morning': 18,
#  'work': 16,
#  'want': 18,
#  'would': 18,
#  'felt': 15,
#  'hour': 14,
#  'recalled': 6,
#  'past': 18,
#  'kindness': 9,
#  'taught': 17,
#  'played': 14,
#  'five': 13,
#  'old': 18,
#  'devoted': 9,
#  'powers': 13,
#  'attach': 6,
#  'amuse': 5,
#  'health': 14,
#  'nursed': 4,
#  'various': 11,
#  'illnesses': 1,
#  'childhood': 10,
#  'large': 16,
#  'debt': 10,
#  'gratitude': 6,
#  'owing': 7,
#  'intercourse': 7,
#  'last': 17,
#  'seven': 14,
#  'equal': 12,
#  'footing': 3,
#  'perfect': 14,
#  'unreserve': 2,
#  'soon': 15,
#  'followed': 16,
#  'isabella': 3,
#  'yet': 18,
#  'dearer': 3,
#  'tenderer': 2,
#  'recollection': 5,
#  'companion': 13,
#  'possessed': 8,
#  'intelligent': 8,
#  'informed': 8,
#  'useful': 10,
#  'knowing': 14,
#  'ways': 15,
#  'interested': 8,
#  'concerns': 7,
#  'peculiarly': 7,
#  'pleasure': 17,
#  'scheme': 9,
#  'could': 18,
#  'speak': 18,
#  'arose': 12,
#  'never': 15,
#  'find': 16,
#  'fault': 14,
#  'bear': 17,
#  'change': 16,
#  'true': 17,
#  'going': 18,
#  'half': 13,
#  'mile': 13,
#  'aware': 10,
#  'great': 18,
#  'must': 18,
#  'difference': 14,
#  'mrs': 8,
#  'advantages': 9,
#  'natural': 12,
#  'domestic': 7,
#  'suffering': 12,
#  'intellectual': 7,
#  'solitude': 9,
#  'dearly': 10,
#  'loved': 12,
#  'meet': 18,
#  'conversation': 12,
#  'rational': 9,
#  'playful': 5,
#  'evil': 13,
#  'actual': 8,
#  'disparity': 3,
#  'ages': 11,
#  'increased': 10,
#  'constitution': 6,
#  'habits': 9,
#  'valetudinarian': 1,
#  'life': 18,
#  'without': 18,
#  'activity': 8,
#  'mind': 16,
#  'body': 16,
#  'older': 13,
#  'though': 18,
#  'everywhere': 10,
#  'friendliness': 6,
#  'heart': 17,
#  'amiable': 8,
#  'talents': 5,
#  'recommended': 6,
#  'time': 18,
#  'comparatively': 7,
#  'removed': 13,
#  'matrimony': 3,
#  'settled': 14,
#  'london': 12,
#  'miles': 12,
#  'beyond': 15,
#  'daily': 10,
#  'reach': 15,
#  'october': 5,
#  'november': 6,
#  'struggled': 10,
#  'hartfield': 1,
#  'christmas': 10,
#  'next': 18,
#  'visit': 15,
#  'husband': 13,
#  'children': 18,
#  'fill': 16,
#  'give': 15,
#  'society': 11,
#  'highbury': 1,
#  'populous': 6,
#  'village': 11,
#  'almost': 17,
#  'amounting': 3,
#  'town': 13,
#  'spite': 14,
#  'separate': 11,
#  'lawn': 5,
#  'shrubberies': 4,
#  'name': 17,
#  'really': 12,
#  'belong': 12,
#  'afforded': 6,
#  'equals': 7,
#  'woodhouses': 1,
#  'looked': 13,
#  'acquaintance': 8,
#  'universally': 5,
#  'civil': 10,
#  'among': 18,
#  'accepted': 10,
#  'lieu': 2,
#  'melancholy': 11,
#  'sigh': 16,
#  'wish': 18,
#  'impossible': 13,
#  'things': 17,
#  'till': 18,
#  'awoke': 8,
#  'made': 18,
#  'necessary': 12,
#  'cheerful': 13,
#  'spirits': 15,
#  'required': 10,
#  'support': 11,
#  'nervous': 8,
#  'easily': 15,
#  'depressed': 6,
#  'used': 15,
#  'hating': 6,
#  'part': 18,
#  'kind': 16,
#  'origin': 10,
#  'reconciled': 8,
#  'daughter': 15,
#  'marrying': 5,
#  'ever': 15,
#  'compassion': 8,
#  'entirely': 11,
#  'obliged': 10,
#  'selfishness': 7,
#  'able': 14,
#  'suppose': 14,
#  'feel': 15,
#  'differently': 7,
#  'disposed': 9,
#  'done': 18,
#  'sad': 15,
#  'thing': 18,
#  'deal': 13,
#  'happier': 9,
#  'spent': 13,
#  'rest': 17,
#  'smiled': 14,
#  'chatted': 2,
#  'cheerfully': 11,
#  'keep': 16,
#  'thoughts': 16,
#  'tea': 9,
#  'say': 18,
#  'exactly': 14,
#  'said': 18,
#  'poor': 17,
#  'pity': 14,
#  'cannot': 18,
#  'agree': 11,
#  'papa': 4,
#  'know': 18,
#  'good': 18,
#  'humoured': 7,
#  'thoroughly': 9,
#  'deserves': 8,
#  'wife': 15,
#  'live': 15,
#  'us': 15,
#  'odd': 13,
#  'humours': 5,
#  'might': 18,
#  'advantage': 12,
#  'three': 17,
#  'times': 18,
#  'dear': 15,
#  'often': 17,
#  'shall': 17,
#  'see': 18,
#  'coming': 15,
#  'meeting': 16,
#  'begin': 16,
#  'go': 18,
#  'pay': 16,
#  'get': 17,
#  'far': 16,
#  'randalls': 1,
#  'distance': 14,
#  'walk': 17,
#  'nobody': 12,
#  'walking': 17,
#  'carriage': 11,
#  'sure': 17,
#  'james': 6,
#  'like': 18,
#  'put': 18,
#  'horses': 16,
#  'paying': 9,
#  'stable': 8,
#  'already': 16,
#  'talked': 11,
#  'night': 18,
#  'may': 18,
#  'housemaid': 3,
#  'doubt': 18,
#  'whether': 17,
#  'take': 18,
#  'anywhere': 11,
#  'else': 18,
#  'got': 17,
#  'hannah': 2,
#  'mentioned': 11,
#  'glad': 17,
#  'lucky': 10,
#  'slighted': 5,
#  'upon': 14,
#  'account': 14,
#  'make': 18,
#  'servant': 10,
#  'pretty': 15,
#  'spoken': 14,
#  'girl': 13,
#  'opinion': 15,
#  'whenever': 13,
#  'curtseys': 1,
#  'asks': 5,
#  'manner': 14,
#  'needlework': 2,
#  'observe': 10,
#  'turns': 13,
#  'lock': 12,
#  'door': 15,
#  'right': 17,
#  'bangs': 1,
#  'comfort': 16,
#  'somebody': 14,
#  'goes': 17,
#  'hearing': 17,
#  'tell': 18,
#  'spared': 7,
#  'exertions': 6,
#  'maintain': 6,
#  'flow': 11,
#  'ideas': 8,
#  'hoped': 11,
#  'help': 14,
#  'backgammon': 1,
#  'tolerably': 7,
#  'attacked': 6,
#  'regrets': 4,
#  'table': 16,
#  'placed': 13,
#  'visitor': 6,
#  'immediately': 15,
#  'afterwards': 14,
#  'walked': 14,
#  'unnecessary': 8,
#  'knightley': 1,
#  'sensible': 12,
#  'eight': 14,
#  'thirty': 13,
#  'intimate': 7,
#  'connected': 9,
#  'elder': 12,
#  'brother': 16,
#  'frequent': 8,
#  'welcome': 15,
#  'directly': 15,
#  'mutual': 8,
#  'connexions': 3,
#  'returned': 12,
#  'late': 17,
#  'days': 15,
#  'absence': 14,
#  'brunswick': 1,
#  'square': 12,
#  'circumstance': 8,
#  'animated': 7,
#  'inquiries': 6,
#  'answered': 15,
#  'satisfactorily': 2,
#  'gratefully': 7,
#  'observed': 10,
#  'come': 18,
#  'call': 18,
#  'afraid': 15,
#  'shocking': 7,
#  'sir': 15,
#  'beautiful': 13,
#  'moonlight': 8,
#  'mild': 10,
#  'draw': 17,
#  'back': 18,
#  'fire': 17,
#  'found': 18,
#  'damp': 8,
#  'dirty': 9,
#  'catch': 16,
#  'cold': 17,
#  'look': 18,
#  'shoes': 9,
#  'speck': 3,
#  'quite': 17,
#  'surprising': 7,
#  'vast': 9,
#  'rain': 13,
#  'rained': 5,
#  'dreadfully': 7,
#  'hard': 17,
#  'breakfast': 10,
#  'wanted': 14,
#  'bye': 9,
#  'joy': 13,
#  'sort': 15,
#  'feeling': 16,
#  'hurry': 12,
#  'congratulations': 2,
#  'hope': 17,
#  'went': 18,
#  'behave': 9,
#  'cried': 17,
#  'ah': 16,
#  'tis': 11,
#  'business': 14,
#  'please': 18,
#  'possibly': 13,
#  'regard': 14,
#  'comes': 16,
#  'question': 17,
#  'dependence': 5,
#  'independence': 6,
#  'rate': 13,
#  'better': 17,
#  'especially': 14,
#  'fanciful': 5,
#  'troublesome': 8,
#  'creature': 15,
#  'playfully': 3,
#  'head': 18,
#  'certainly': 13,
#  'believe': 14,
#  'sometimes': 16,
#  'dearest': 10,
#  'mean': 16,
#  'horrible': 12,
#  'idea': 13,
#  'oh': 17,
#  'meant': 16,
#  'loves': 13,
#  'joke': 9,
#  'another': 18,
#  'fact': 14,
#  'faults': 11,
#  'told': 18,
#  'agreeable': 5,
#  'knew': 17,
#  'suspect': 9,
#  'knows': 13,
#  'flatter': 9,
#  'reflection': 13,
#  'persons': 13,
#  'chances': 6,
#  'gainer': 3,
#  'willing': 15,
#  'let': 18,
#  'pass': 14,
#  'hear': 16,
#  'behaved': 7,
#  'charmingly': 2,
#  'punctual': 6,
#  'looks': 13,
#  'tear': 13,
#  'face': 18,
#  'seen': 17,
#  'apart': 13,
#  'bears': 10,
#  'sorry': 16,
#  'lose': 15,
#  'thinks': 11,
#  'turned': 14,
#  'divided': 11,
#  'tears': 14,
#  'smiles': 12,
#  'acceptable': 6,
#  'important': 14,
#  'secure': 11,
#  'provision': 6,
#  'therefore': 17,
#  'allow': 14,
#  'pain': 12,
#  'happily': 10,
#  'forgotten': 15,
#  'matter': 17,
#  'considerable': 9,
#  'four': 13,
#  'proved': 12,
#  'marry': 11,
#  'shook': 14,
#  'fondly': 5,
#  'replied': 12,
#  'matches': 5,
#  'foretell': 4,
#  'whatever': 13,
#  'pray': 17,
#  'none': 18,
#  'greatest': 12,
#  'amusement': 7,
#  'success': 11,
#  'widower': 4,
#  'perfectly': 14,
#  'constantly': 11,
#  'occupied': 9,
#  'either': 17,
#  'friends': 17,
#  'wherever': 13,
#  'need': 16,
#  'spend': 11,
#  'single': 15,
#  'year': 14,
#  'alone': 18,
#  'deathbed': 2,
#  'others': 17,
#  'son': 15,
#  'uncle': 9,
#  'letting': 11,
#  'solemn': 13,
#  'nonsense': 11,
#  'subject': 12,
#  'believed': 12,
#  'since': 17,
#  'met': 18,
#  'broadway': 3,
#  'lane': 10,
#  'began': 17,
#  'drizzle': 1,
#  'darted': 8,
#  'gallantry': 5,
#  'borrowed': 9,
#  'umbrellas': 3,
#  'farmer': 9,
#  'mitchell': 1,
#  'planned': 7,
#  'blessed': 13,
#  'instance': 10,
#  'leave': 15,
#  'making': 18,
#  'understand': 14,
#  'supposes': 5,
#  'endeavour': 6,
#  'properly': 10,
#  'delicately': 5,
#  'endeavouring': 7,
#  'bring': 16,
#  'worthy': 15,
#  'employment': 8,
#  'young': 18,
#  'lady': 15,
#  'imagine': 13,
#  'planning': 4,
#  'saying': 18,
#  'idle': 14,
#  'talk': 17,
#  'merit': 9,
#  'proud': 17,
#  'guess': 13,
#  'known': 16,
#  'triumph': 13,
#  'cleverer': 3,
#  'depend': 9,
#  'merely': 12,
#  'luck': 10,
#  'talent': 5,
#  'word': 18,
#  'quarrel': 12,
#  'claim': 9,
#  'drawn': 12,
#  'pictures': 13,
#  'something': 17,
#  'nothing': 18,
#  'visits': 5,
#  'given': 15,
#  'encouragements': 2,
#  'smoothed': 4,
#  'matters': 15,
#  'enough': 17,
#  'comprehend': 9,
#  'straightforward': 2,
#  'open': 17,
#  'hearted': 10,
#  'unaffected': 6,
#  'safely': 14,
#  'manage': 11,
#  'likely': 13,
#  'harm': 13,
#  'interference': 6,
#  'rejoined': 7,
#  'understanding': 10,
#  'silly': 11,
#  'break': 15,
#  'circle': 14,
#  'grievously': 2,
#  'elton': 1,
#  'whole': 17,
#  'fitted': 12,
#  'comfortably': 11,
#  'shame': 17,
#  'longer': 16,
#  'joining': 8,
#  'hands': 17,
#  'service': 12,
#  'shew': 7,
#  'attention': 10,
#  'ask': 17,
#  'dare': 18,
#  'laughing': 14,
#  'invite': 7,
#  'fish': 13,
#  'chicken': 4,
#  'chuse': 2,
#  'six': 14,
#  'care': 17,
#  'ii': 13,
#  'native': 9,
#  'born': 13,
#  'respectable': 10,
#  'generations': 8,
#  'rising': 14,
#  'gentility': 3,
#  'property': 10,
#  'received': 12,
#  'education': 9,
#  'succeeding': 6,
#  'small': 16,
#  'become': 17,
#  'indisposed': 3,
#  'homely': 7,
#  'pursuits': 5,
#  'brothers': 14,
#  'engaged': 13,
#  'satisfied': 14,
#  'active': 9,
#  'social': 9,
#  'entering': 9,
#  'militia': 3,
#  'county': 7,
#  'embodied': 4,
#  'captain': 9,
#  'general': 12,
#  'favourite': 10,
#  'military': 9,
#  'introduced': 9,
#  'churchill': 2,
#  'yorkshire': 3,
#  'fell': 17,
#  'love': 15,
#  'surprized': 2,
#  'except': 17,
#  'full': 18,
#  'pride': 15,
#  'importance': 9,
#  'connexion': 5,
#  'offend': 11,
#  'command': 14,
#  'bore': 16,
#  'proportion': 11,
#  'estate': 12,
#  'dissuaded': 1,
#  'took': 15,
#  'infinite': 10,
#  'mortification': 4,
#  'threw': 16,
#  'due': 13,
#  'decorum': 5,
#  'unsuitable': 2,
#  'produce': 11,
#  'ought': 16,
#  'whose': 18,
#  'warm': 15,
#  'sweet': 18,
#  'return': 14,
#  'goodness': 11,
#  'spirit': 17,
#  'resolution': 11,
#  'pursue': 10,
#  'refrain': 6,
#  'unreasonable': 8,
#  'anger': 17,
#  'missing': 10,
#  'luxuries': 2,
#  'former': 15,
#  'income': 6,
#  'still': 18,
#  'comparison': 10,
#  'enscombe': 1,
#  'cease': 14,
#  'considered': 13,
#  'churchills': 1,
#  'amazing': 4,
#  'worst': 16,
#  'bargain': 8,
#  'poorer': 4,
#  'child': 14,
#  'expense': 7,
#  'relieved': 9,
#  'boy': 17,
#  'additional': 8,
#  'softening': 4,
#  'lingering': 8,
#  'illness': 6,
#  'reconciliation': 7,
#  'kindred': 5,
#  'offered': 13,
#  'charge': 15,
#  'frank': 6,
#  'decease': 5,
#  'scruples': 7,
#  'reluctance': 6,
#  'supposed': 13,
#  'overcome': 9,
#  'considerations': 3,
#  'wealth': 11,
#  'seek': 15,
#  'improve': 7,
#  'complete': 11,
#  'became': 17,
#  'desirable': 7,
#  'quitted': 8,
#  'trade': 11,
#  'established': 9,
#  'favourable': 7,
#  'opening': 15,
#  'concern': 11,
#  'leisure': 10,
#  'occupation': 9,
#  'pleasures': 13,
#  'eighteen': 7,
#  'realised': 3,
#  'competence': 2,
#  'purchase': 8,
#  'adjoining': 6,
#  'longed': 10,
#  'portionless': 1,
#  'according': 14,
#  'wishes': 9,
#  'friendly': 13,
#  'begun': 17,
#  'influence': 10,
#  'schemes': 8,
#  'tyrannic': 2,
#  'youth': 15,
#  'shaken': 11,
#  'determination': 8,
#  'settling': 8,
#  'sale': 5,
#  'forward': 13,
#  'steadily': 9,
#  'objects': 11,
#  'view': 15,
#  'accomplished': 7,
#  'bought': 11,
#  'obtained': 7,
#  'beginning': 15,
#  'new': 17,
#  'probability': 8,
#  'greater': 15,
#  'unhappy': 12,
#  'secured': 7,
#  'second': 17,
#  'delightful': 10,
#  'judging': 9,
#  'truly': 15,
#  'pleasantest': 5,
#  'proof': 10,
#  'choose': 14,
#  'chosen': 13,
#  'excite': 7,
#  'choice': 14,
#  'tacitly': 2,
#  'heir': 9,
#  'avowed': 2,
#  'adoption': 5,
#  'assume': 10,
#  'unlikely': 5,
#  'assistance': 8,
#  'apprehension': 7,
#  'aunt': 9,
#  'capricious': 4,
#  'governed': 7,
#  'nature': 17,
#  'caprice': 7,
#  'strong': 16,
#  'affect': 9,
#  'deservedly': 2,
#  'saw': 18,
#  'report': 14,
#  'fine': 15,
#  'sufficiently': 10,
#  'belonging': 7,
#  'merits': 8,
#  'prospects': 4,
#  'common': 17,
#  'boasts': 2,
#  'lively': 11,
#  'curiosity': 12,
#  'prevailed': 8,
#  'compliment': 9,
#  'achieved': 5,
#  'generally': 12,
#  'proposed': 9,
#  'proper': 16,
#  'dissentient': 1,
#  'voice': 17,
#  'perry': 2,
#  'drank': 9,
#  'bates': 2,
#  'strengthened': 4,
#  'understood': 14,
#  'written': 15,
#  'occasion': 13,
#  'included': 7,
#  'mention': 12,
#  'letter': 14,
#  'heard': 18,
#  'says': 12,
#  'prized': 3,
#  'course': 17,
#  'formed': 11,
#  'pleasing': 13,
#  'irresistible': 6,
#  'sense': 16,
#  'addition': 12,
#  'source': 8,
#  'expression': 11,
#  'congratulation': 3,
#  'fortunate': 6,
#  'regret': 7,
#  'partial': 10,
#  'separation': 7,
#  'cooled': 5,
#  'ill': 16,
#  'missed': 10,
#  'losing': 10,
#  'ennui': 3,
#  'companionableness': 2,
#  'feeble': 11,
#  'girls': 12,
#  'energy': 9,
#  'difficulties': 8,
#  'privations': 3,
#  'convenient': 8,
#  'solitary': 11,
#  'female': 10,
#  'circumstances': 11,
#  'approaching': 10,
#  'season': 14,
#  'hindrance': 3,
#  'spending': 7,
#  'evenings': 8,
#  'week': 12,
#  'altogether': 15,
#  'hours': 13,
#  'moments': 9,
#  'enjoyment': 9,
#  'apparent': 10,
#  'taken': 16,
#  'surprize': 2,
#  'centre': 10,
#  'attended': 12,
#  'giving': 14,
#  'stay': 15,
#  'recovering': 8,
#  'likelihood': 3,
#  'ceasing': 7,
#  'weeks': 11,
#  'alleviation': 2,
#  'compliments': 6,
#  'neighbours': 8,
#  'teased': 1,
#  'sorrowful': 8,
#  'cake': 8,
#  'eat': 15,
#  'stomach': 9,
#  'different': 14,
#  'unwholesome': 2,
#  'regarded': 10,
#  'unfit': 5,
#  'earnestly': 12,
#  'tried': 15,
#  ...}

# %% [markdown]
# ### Exercise 2.1
# * Write a function which will compute the idf values for features given a list of documents
# * Use it to compute idf values for features given the entire list of books in the book collection

# %%
import math

def idf(doclist):
    N=len(doclist)
    return {feat:math.log(N/v) for feat,v in doc_freq(doclist).items()}

# %%
books_idf=idf(book_reps.values())
books_idf
# Out:
# {'emma': 2.1972245773362196,
#  'jane': 1.791759469228055,
#  'austen': 1.791759469228055,
#  'volume': 0.49247648509779424,
#  'chapter': 0.8109302162163288,
#  'woodhouse': 2.8903717578961645,
#  'handsome': 0.49247648509779424,
#  'clever': 0.5877866649021191,
#  'rich': 0.05715841383994862,
#  'comfortable': 0.32542240043462795,
#  'home': 0.0,
#  'happy': 0.0,
#  'disposition': 0.5877866649021191,
#  'seemed': 0.1823215567939546,
#  'unite': 1.0986122886681098,
#  'best': 0.0,
#  'blessings': 0.9444616088408515,
#  'existence': 0.5877866649021191,
#  'lived': 0.25131442828090617,
#  'nearly': 0.32542240043462795,
#  'twenty': 0.11778303565638346,
#  'one': 0.0,
#  'years': 0.1823215567939546,
#  'world': 0.0,
#  'little': 0.0,
#  'distress': 0.4054651081081644,
#  'vex': 0.9444616088408515,
#  'youngest': 0.5877866649021191,
#  'two': 0.0,
#  'daughters': 0.49247648509779424,
#  'affectionate': 0.8109302162163288,
#  'indulgent': 1.0986122886681098,
#  'father': 0.05715841383994862,
#  'consequence': 0.32542240043462795,
#  'sister': 0.25131442828090617,
#  'marriage': 0.4054651081081644,
#  'mistress': 0.5877866649021191,
#  'house': 0.0,
#  'early': 0.25131442828090617,
#  'period': 0.8109302162163288,
#  'mother': 0.05715841383994862,
#  'died': 0.1823215567939546,
#  'long': 0.0,
#  'ago': 0.25131442828090617,
#  'indistinct': 1.791759469228055,
#  'remembrance': 0.5877866649021191,
#  'caresses': 1.2809338454620642,
#  'place': 0.0,
#  'supplied': 0.8109302162163288,
#  'excellent': 0.32542240043462795,
#  'woman': 0.05715841383994862,
#  'governess': 1.791759469228055,
#  'fallen': 0.1823215567939546,
#  'short': 0.11778303565638346,
#  'affection': 0.4054651081081644,
#  'sixteen': 0.9444616088408515,
#  'miss': 0.32542240043462795,
#  'taylor': 1.791759469228055,
#  'mr': 0.5877866649021191,
#  'family': 0.32542240043462795,
#  'less': 0.25131442828090617,
#  'friend': 0.0,
#  'fond': 0.25131442828090617,
#  'particularly': 0.6931471805599453,
#  'intimacy': 1.0986122886681098,
#  'sisters': 0.4054651081081644,
#  'even': 0.25131442828090617,
#  'ceased': 0.5877866649021191,
#  'hold': 0.05715841383994862,
#  'nominal': 1.791759469228055,
#  'office': 0.1823215567939546,
#  'mildness': 0.8109302162163288,
#  'temper': 0.1823215567939546,
#  'hardly': 0.11778303565638346,
#  'allowed': 0.49247648509779424,
#  'impose': 1.0986122886681098,
#  'restraint': 0.5877866649021191,
#  'shadow': 0.1823215567939546,
#  'authority': 0.4054651081081644,
#  'passed': 0.32542240043462795,
#  'away': 0.0,
#  'living': 0.32542240043462795,
#  'together': 0.05715841383994862,
#  'mutually': 1.5040773967762742,
#  'attached': 0.6931471805599453,
#  'liked': 0.4054651081081644,
#  'highly': 0.32542240043462795,
#  'esteeming': 1.791759469228055,
#  'judgment': 1.0986122886681098,
#  'directed': 0.5877866649021191,
#  'chiefly': 0.6931471805599453,
#  'real': 0.32542240043462795,
#  'evils': 0.9444616088408515,
#  'indeed': 0.0,
#  'situation': 0.5877866649021191,
#  'power': 0.11778303565638346,
#  'rather': 0.05715841383994862,
#  'much': 0.05715841383994862,
#  'way': 0.0,
#  'think': 0.0,
#  'well': 0.0,
#  'disadvantages': 1.791759469228055,
#  'threatened': 0.8109302162163288,
#  'alloy': 1.791759469228055,
#  'many': 0.0,
#  'enjoyments': 1.0986122886681098,
#  'danger': 0.11778303565638346,
#  'however': 0.32542240043462795,
#  'present': 0.11778303565638346,
#  'unperceived': 1.791759469228055,
#  'means': 0.32542240043462795,
#  'rank': 0.32542240043462795,
#  'misfortunes': 1.2809338454620642,
#  'sorrow': 0.05715841383994862,
#  'came': 0.0,
#  'gentle': 0.11778303565638346,
#  'shape': 0.11778303565638346,
#  'disagreeable': 1.2809338454620642,
#  'consciousness': 1.0986122886681098,
#  'married': 0.49247648509779424,
#  'loss': 0.4054651081081644,
#  'first': 0.05715841383994862,
#  'brought': 0.0,
#  'grief': 0.4054651081081644,
#  'wedding': 0.5877866649021191,
#  'day': 0.0,
#  'beloved': 0.5877866649021191,
#  'sat': 0.1823215567939546,
#  'mournful': 1.0986122886681098,
#  'thought': 0.0,
#  'continuance': 1.5040773967762742,
#  'bride': 0.9444616088408515,
#  'people': 0.05715841383994862,
#  'gone': 0.0,
#  'left': 0.0,
#  'dine': 0.9444616088408515,
#  'prospect': 0.8109302162163288,
#  'third': 0.1823215567939546,
#  'cheer': 0.6931471805599453,
#  'evening': 0.25131442828090617,
#  'composed': 0.6931471805599453,
#  'sleep': 0.11778303565638346,
#  'dinner': 0.1823215567939546,
#  'usual': 0.4054651081081644,
#  'sit': 0.0,
#  'lost': 0.0,
#  'event': 0.5877866649021191,
#  'every': 0.1823215567939546,
#  'promise': 0.1823215567939546,
#  'happiness': 0.49247648509779424,
#  'weston': 2.8903717578961645,
#  'man': 0.0,
#  'unexceptionable': 2.1972245773362196,
#  'character': 0.4054651081081644,
#  'easy': 0.25131442828090617,
#  'fortune': 0.4054651081081644,
#  'suitable': 0.9444616088408515,
#  'age': 0.0,
#  'pleasant': 0.05715841383994862,
#  'manners': 0.4054651081081644,
#  'satisfaction': 0.4054651081081644,
#  'considering': 0.6931471805599453,
#  'self': 0.1823215567939546,
#  'denying': 0.8109302162163288,
#  'generous': 0.5877866649021191,
#  'friendship': 0.25131442828090617,
#  'always': 0.1823215567939546,
#  'wished': 0.5877866649021191,
#  'promoted': 1.5040773967762742,
#  'match': 0.8109302162163288,
#  'black': 0.1823215567939546,
#  'morning': 0.0,
#  'work': 0.11778303565638346,
#  'want': 0.0,
#  'would': 0.0,
#  'felt': 0.1823215567939546,
#  'hour': 0.25131442828090617,
#  'recalled': 1.0986122886681098,
#  'past': 0.0,
#  'kindness': 0.6931471805599453,
#  'taught': 0.05715841383994862,
#  'played': 0.25131442828090617,
#  'five': 0.32542240043462795,
#  'old': 0.0,
#  'devoted': 0.6931471805599453,
#  'powers': 0.32542240043462795,
#  'attach': 1.0986122886681098,
#  'amuse': 1.2809338454620642,
#  'health': 0.25131442828090617,
#  'nursed': 1.5040773967762742,
#  'various': 0.49247648509779424,
#  'illnesses': 2.8903717578961645,
#  'childhood': 0.5877866649021191,
#  'large': 0.11778303565638346,
#  'debt': 0.5877866649021191,
#  'gratitude': 1.0986122886681098,
#  'owing': 0.9444616088408515,
#  'intercourse': 0.9444616088408515,
#  'last': 0.05715841383994862,
#  'seven': 0.25131442828090617,
#  'equal': 0.4054651081081644,
#  'footing': 1.791759469228055,
#  'perfect': 0.25131442828090617,
#  'unreserve': 2.1972245773362196,
#  'soon': 0.1823215567939546,
#  'followed': 0.11778303565638346,
#  'isabella': 1.791759469228055,
#  'yet': 0.0,
#  'dearer': 1.791759469228055,
#  'tenderer': 2.1972245773362196,
#  'recollection': 1.2809338454620642,
#  'companion': 0.32542240043462795,
#  'possessed': 0.8109302162163288,
#  'intelligent': 0.8109302162163288,
#  'informed': 0.8109302162163288,
#  'useful': 0.5877866649021191,
#  'knowing': 0.25131442828090617,
#  'ways': 0.1823215567939546,
#  'interested': 0.8109302162163288,
#  'concerns': 0.9444616088408515,
#  'peculiarly': 0.9444616088408515,
#  'pleasure': 0.05715841383994862,
#  'scheme': 0.6931471805599453,
#  'could': 0.0,
#  'speak': 0.0,
#  'arose': 0.4054651081081644,
#  'never': 0.1823215567939546,
#  'find': 0.11778303565638346,
#  'fault': 0.25131442828090617,
#  'bear': 0.05715841383994862,
#  'change': 0.11778303565638346,
#  'true': 0.05715841383994862,
#  'going': 0.0,
#  'half': 0.32542240043462795,
#  'mile': 0.32542240043462795,
#  'aware': 0.5877866649021191,
#  'great': 0.0,
#  'must': 0.0,
#  'difference': 0.25131442828090617,
#  'mrs': 0.8109302162163288,
#  'advantages': 0.6931471805599453,
#  'natural': 0.4054651081081644,
#  'domestic': 0.9444616088408515,
#  'suffering': 0.4054651081081644,
#  'intellectual': 0.9444616088408515,
#  'solitude': 0.6931471805599453,
#  'dearly': 0.5877866649021191,
#  'loved': 0.4054651081081644,
#  'meet': 0.0,
#  'conversation': 0.4054651081081644,
#  'rational': 0.6931471805599453,
#  'playful': 1.2809338454620642,
#  'evil': 0.32542240043462795,
#  'actual': 0.8109302162163288,
#  'disparity': 1.791759469228055,
#  'ages': 0.49247648509779424,
#  'increased': 0.5877866649021191,
#  'constitution': 1.0986122886681098,
#  'habits': 0.6931471805599453,
#  'valetudinarian': 2.8903717578961645,
#  'life': 0.0,
#  'without': 0.0,
#  'activity': 0.8109302162163288,
#  'mind': 0.11778303565638346,
#  'body': 0.11778303565638346,
#  'older': 0.32542240043462795,
#  'though': 0.0,
#  'everywhere': 0.5877866649021191,
#  'friendliness': 1.0986122886681098,
#  'heart': 0.05715841383994862,
#  'amiable': 0.8109302162163288,
#  'talents': 1.2809338454620642,
#  'recommended': 1.0986122886681098,
#  'time': 0.0,
#  'comparatively': 0.9444616088408515,
#  'removed': 0.32542240043462795,
#  'matrimony': 1.791759469228055,
#  'settled': 0.25131442828090617,
#  'london': 0.4054651081081644,
#  'miles': 0.4054651081081644,
#  'beyond': 0.1823215567939546,
#  'daily': 0.5877866649021191,
#  'reach': 0.1823215567939546,
#  'october': 1.2809338454620642,
#  'november': 1.0986122886681098,
#  'struggled': 0.5877866649021191,
#  'hartfield': 2.8903717578961645,
#  'christmas': 0.5877866649021191,
#  'next': 0.0,
#  'visit': 0.1823215567939546,
#  'husband': 0.32542240043462795,
#  'children': 0.0,
#  'fill': 0.11778303565638346,
#  'give': 0.1823215567939546,
#  'society': 0.49247648509779424,
#  'highbury': 2.8903717578961645,
#  'populous': 1.0986122886681098,
#  'village': 0.49247648509779424,
#  'almost': 0.05715841383994862,
#  'amounting': 1.791759469228055,
#  'town': 0.32542240043462795,
#  'spite': 0.25131442828090617,
#  'separate': 0.49247648509779424,
#  'lawn': 1.2809338454620642,
#  'shrubberies': 1.5040773967762742,
#  'name': 0.05715841383994862,
#  'really': 0.4054651081081644,
#  'belong': 0.4054651081081644,
#  'afforded': 1.0986122886681098,
#  'equals': 0.9444616088408515,
#  'woodhouses': 2.8903717578961645,
#  'looked': 0.32542240043462795,
#  'acquaintance': 0.8109302162163288,
#  'universally': 1.2809338454620642,
#  'civil': 0.5877866649021191,
#  'among': 0.0,
#  'accepted': 0.5877866649021191,
#  'lieu': 2.1972245773362196,
#  'melancholy': 0.49247648509779424,
#  'sigh': 0.11778303565638346,
#  'wish': 0.0,
#  'impossible': 0.32542240043462795,
#  'things': 0.05715841383994862,
#  'till': 0.0,
#  'awoke': 0.8109302162163288,
#  'made': 0.0,
#  'necessary': 0.4054651081081644,
#  'cheerful': 0.32542240043462795,
#  'spirits': 0.1823215567939546,
#  'required': 0.5877866649021191,
#  'support': 0.49247648509779424,
#  'nervous': 0.8109302162163288,
#  'easily': 0.1823215567939546,
#  'depressed': 1.0986122886681098,
#  'used': 0.1823215567939546,
#  'hating': 1.0986122886681098,
#  'part': 0.0,
#  'kind': 0.11778303565638346,
#  'origin': 0.5877866649021191,
#  'reconciled': 0.8109302162163288,
#  'daughter': 0.1823215567939546,
#  'marrying': 1.2809338454620642,
#  'ever': 0.1823215567939546,
#  'compassion': 0.8109302162163288,
#  'entirely': 0.49247648509779424,
#  'obliged': 0.5877866649021191,
#  'selfishness': 0.9444616088408515,
#  'able': 0.25131442828090617,
#  'suppose': 0.25131442828090617,
#  'feel': 0.1823215567939546,
#  'differently': 0.9444616088408515,
#  'disposed': 0.6931471805599453,
#  'done': 0.0,
#  'sad': 0.1823215567939546,
#  'thing': 0.0,
#  'deal': 0.32542240043462795,
#  'happier': 0.6931471805599453,
#  'spent': 0.32542240043462795,
#  'rest': 0.05715841383994862,
#  'smiled': 0.25131442828090617,
#  'chatted': 2.1972245773362196,
#  'cheerfully': 0.49247648509779424,
#  'keep': 0.11778303565638346,
#  'thoughts': 0.11778303565638346,
#  'tea': 0.6931471805599453,
#  'say': 0.0,
#  'exactly': 0.25131442828090617,
#  'said': 0.0,
#  'poor': 0.05715841383994862,
#  'pity': 0.25131442828090617,
#  'cannot': 0.0,
#  'agree': 0.49247648509779424,
#  'papa': 1.5040773967762742,
#  'know': 0.0,
#  'good': 0.0,
#  'humoured': 0.9444616088408515,
#  'thoroughly': 0.6931471805599453,
#  'deserves': 0.8109302162163288,
#  'wife': 0.1823215567939546,
#  'live': 0.1823215567939546,
#  'us': 0.1823215567939546,
#  'odd': 0.32542240043462795,
#  'humours': 1.2809338454620642,
#  'might': 0.0,
#  'advantage': 0.4054651081081644,
#  'three': 0.05715841383994862,
#  'times': 0.0,
#  'dear': 0.1823215567939546,
#  'often': 0.05715841383994862,
#  'shall': 0.05715841383994862,
#  'see': 0.0,
#  'coming': 0.1823215567939546,
#  'meeting': 0.11778303565638346,
#  'begin': 0.11778303565638346,
#  'go': 0.0,
#  'pay': 0.11778303565638346,
#  'get': 0.05715841383994862,
#  'far': 0.11778303565638346,
#  'randalls': 2.8903717578961645,
#  'distance': 0.25131442828090617,
#  'walk': 0.05715841383994862,
#  'nobody': 0.4054651081081644,
#  'walking': 0.05715841383994862,
#  'carriage': 0.49247648509779424,
#  'sure': 0.05715841383994862,
#  'james': 1.0986122886681098,
#  'like': 0.0,
#  'put': 0.0,
#  'horses': 0.11778303565638346,
#  'paying': 0.6931471805599453,
#  'stable': 0.8109302162163288,
#  'already': 0.11778303565638346,
#  'talked': 0.49247648509779424,
#  'night': 0.0,
#  'may': 0.0,
#  'housemaid': 1.791759469228055,
#  'doubt': 0.0,
#  'whether': 0.05715841383994862,
#  'take': 0.0,
#  'anywhere': 0.49247648509779424,
#  'else': 0.0,
#  'got': 0.05715841383994862,
#  'hannah': 2.1972245773362196,
#  'mentioned': 0.49247648509779424,
#  'glad': 0.05715841383994862,
#  'lucky': 0.5877866649021191,
#  'slighted': 1.2809338454620642,
#  'upon': 0.25131442828090617,
#  'account': 0.25131442828090617,
#  'make': 0.0,
#  'servant': 0.5877866649021191,
#  'pretty': 0.1823215567939546,
#  'spoken': 0.25131442828090617,
#  'girl': 0.32542240043462795,
#  'opinion': 0.1823215567939546,
#  'whenever': 0.32542240043462795,
#  'curtseys': 2.8903717578961645,
#  'asks': 1.2809338454620642,
#  'manner': 0.25131442828090617,
#  'needlework': 2.1972245773362196,
#  'observe': 0.5877866649021191,
#  'turns': 0.32542240043462795,
#  'lock': 0.4054651081081644,
#  'door': 0.1823215567939546,
#  'right': 0.05715841383994862,
#  'bangs': 2.8903717578961645,
#  'comfort': 0.11778303565638346,
#  'somebody': 0.25131442828090617,
#  'goes': 0.05715841383994862,
#  'hearing': 0.05715841383994862,
#  'tell': 0.0,
#  'spared': 0.9444616088408515,
#  'exertions': 1.0986122886681098,
#  'maintain': 1.0986122886681098,
#  'flow': 0.49247648509779424,
#  'ideas': 0.8109302162163288,
#  'hoped': 0.49247648509779424,
#  'help': 0.25131442828090617,
#  'backgammon': 2.8903717578961645,
#  'tolerably': 0.9444616088408515,
#  'attacked': 1.0986122886681098,
#  'regrets': 1.5040773967762742,
#  'table': 0.11778303565638346,
#  'placed': 0.32542240043462795,
#  'visitor': 1.0986122886681098,
#  'immediately': 0.1823215567939546,
#  'afterwards': 0.25131442828090617,
#  'walked': 0.25131442828090617,
#  'unnecessary': 0.8109302162163288,
#  'knightley': 2.8903717578961645,
#  'sensible': 0.4054651081081644,
#  'eight': 0.25131442828090617,
#  'thirty': 0.32542240043462795,
#  'intimate': 0.9444616088408515,
#  'connected': 0.6931471805599453,
#  'elder': 0.4054651081081644,
#  'brother': 0.11778303565638346,
#  'frequent': 0.8109302162163288,
#  'welcome': 0.1823215567939546,
#  'directly': 0.1823215567939546,
#  'mutual': 0.8109302162163288,
#  'connexions': 1.791759469228055,
#  'returned': 0.4054651081081644,
#  'late': 0.05715841383994862,
#  'days': 0.1823215567939546,
#  'absence': 0.25131442828090617,
#  'brunswick': 2.8903717578961645,
#  'square': 0.4054651081081644,
#  'circumstance': 0.8109302162163288,
#  'animated': 0.9444616088408515,
#  'inquiries': 1.0986122886681098,
#  'answered': 0.1823215567939546,
#  'satisfactorily': 2.1972245773362196,
#  'gratefully': 0.9444616088408515,
#  'observed': 0.5877866649021191,
#  'come': 0.0,
#  'call': 0.0,
#  'afraid': 0.1823215567939546,
#  'shocking': 0.9444616088408515,
#  'sir': 0.1823215567939546,
#  'beautiful': 0.32542240043462795,
#  'moonlight': 0.8109302162163288,
#  'mild': 0.5877866649021191,
#  'draw': 0.05715841383994862,
#  'back': 0.0,
#  'fire': 0.05715841383994862,
#  'found': 0.0,
#  'damp': 0.8109302162163288,
#  'dirty': 0.6931471805599453,
#  'catch': 0.11778303565638346,
#  'cold': 0.05715841383994862,
#  'look': 0.0,
#  'shoes': 0.6931471805599453,
#  'speck': 1.791759469228055,
#  'quite': 0.05715841383994862,
#  'surprising': 0.9444616088408515,
#  'vast': 0.6931471805599453,
#  'rain': 0.32542240043462795,
#  'rained': 1.2809338454620642,
#  'dreadfully': 0.9444616088408515,
#  'hard': 0.05715841383994862,
#  'breakfast': 0.5877866649021191,
#  'wanted': 0.25131442828090617,
#  'bye': 0.6931471805599453,
#  'joy': 0.32542240043462795,
#  'sort': 0.1823215567939546,
#  'feeling': 0.11778303565638346,
#  'hurry': 0.4054651081081644,
#  'congratulations': 2.1972245773362196,
#  'hope': 0.05715841383994862,
#  'went': 0.0,
#  'behave': 0.6931471805599453,
#  'cried': 0.05715841383994862,
#  'ah': 0.11778303565638346,
#  'tis': 0.49247648509779424,
#  'business': 0.25131442828090617,
#  'please': 0.0,
#  'possibly': 0.32542240043462795,
#  'regard': 0.25131442828090617,
#  'comes': 0.11778303565638346,
#  'question': 0.05715841383994862,
#  'dependence': 1.2809338454620642,
#  'independence': 1.0986122886681098,
#  'rate': 0.32542240043462795,
#  'better': 0.05715841383994862,
#  'especially': 0.25131442828090617,
#  'fanciful': 1.2809338454620642,
#  'troublesome': 0.8109302162163288,
#  'creature': 0.1823215567939546,
#  'playfully': 1.791759469228055,
#  'head': 0.0,
#  'certainly': 0.32542240043462795,
#  'believe': 0.25131442828090617,
#  'sometimes': 0.11778303565638346,
#  'dearest': 0.5877866649021191,
#  'mean': 0.11778303565638346,
#  'horrible': 0.4054651081081644,
#  'idea': 0.32542240043462795,
#  'oh': 0.05715841383994862,
#  'meant': 0.11778303565638346,
#  'loves': 0.32542240043462795,
#  'joke': 0.6931471805599453,
#  'another': 0.0,
#  'fact': 0.25131442828090617,
#  'faults': 0.49247648509779424,
#  'told': 0.0,
#  'agreeable': 1.2809338454620642,
#  'knew': 0.05715841383994862,
#  'suspect': 0.6931471805599453,
#  'knows': 0.32542240043462795,
#  'flatter': 0.6931471805599453,
#  'reflection': 0.32542240043462795,
#  'persons': 0.32542240043462795,
#  'chances': 1.0986122886681098,
#  'gainer': 1.791759469228055,
#  'willing': 0.1823215567939546,
#  'let': 0.0,
#  'pass': 0.25131442828090617,
#  'hear': 0.11778303565638346,
#  'behaved': 0.9444616088408515,
#  'charmingly': 2.1972245773362196,
#  'punctual': 1.0986122886681098,
#  'looks': 0.32542240043462795,
#  'tear': 0.32542240043462795,
#  'face': 0.0,
#  'seen': 0.05715841383994862,
#  'apart': 0.32542240043462795,
#  'bears': 0.5877866649021191,
#  'sorry': 0.11778303565638346,
#  'lose': 0.1823215567939546,
#  'thinks': 0.49247648509779424,
#  'turned': 0.25131442828090617,
#  'divided': 0.49247648509779424,
#  'tears': 0.25131442828090617,
#  'smiles': 0.4054651081081644,
#  'acceptable': 1.0986122886681098,
#  'important': 0.25131442828090617,
#  'secure': 0.49247648509779424,
#  'provision': 1.0986122886681098,
#  'therefore': 0.05715841383994862,
#  'allow': 0.25131442828090617,
#  'pain': 0.4054651081081644,
#  'happily': 0.5877866649021191,
#  'forgotten': 0.1823215567939546,
#  'matter': 0.05715841383994862,
#  'considerable': 0.6931471805599453,
#  'four': 0.32542240043462795,
#  'proved': 0.4054651081081644,
#  'marry': 0.49247648509779424,
#  'shook': 0.25131442828090617,
#  'fondly': 1.2809338454620642,
#  'replied': 0.4054651081081644,
#  'matches': 1.2809338454620642,
#  'foretell': 1.5040773967762742,
#  'whatever': 0.32542240043462795,
#  'pray': 0.05715841383994862,
#  'none': 0.0,
#  'greatest': 0.4054651081081644,
#  'amusement': 0.9444616088408515,
#  'success': 0.49247648509779424,
#  'widower': 1.5040773967762742,
#  'perfectly': 0.25131442828090617,
#  'constantly': 0.49247648509779424,
#  'occupied': 0.6931471805599453,
#  'either': 0.05715841383994862,
#  'friends': 0.05715841383994862,
#  'wherever': 0.32542240043462795,
#  'need': 0.11778303565638346,
#  'spend': 0.49247648509779424,
#  'single': 0.1823215567939546,
#  'year': 0.25131442828090617,
#  'alone': 0.0,
#  'deathbed': 2.1972245773362196,
#  'others': 0.05715841383994862,
#  'son': 0.1823215567939546,
#  'uncle': 0.6931471805599453,
#  'letting': 0.49247648509779424,
#  'solemn': 0.32542240043462795,
#  'nonsense': 0.49247648509779424,
#  'subject': 0.4054651081081644,
#  'believed': 0.4054651081081644,
#  'since': 0.05715841383994862,
#  'met': 0.0,
#  'broadway': 1.791759469228055,
#  'lane': 0.5877866649021191,
#  'began': 0.05715841383994862,
#  'drizzle': 2.8903717578961645,
#  'darted': 0.8109302162163288,
#  'gallantry': 1.2809338454620642,
#  'borrowed': 0.6931471805599453,
#  'umbrellas': 1.791759469228055,
#  'farmer': 0.6931471805599453,
#  'mitchell': 2.8903717578961645,
#  'planned': 0.9444616088408515,
#  'blessed': 0.32542240043462795,
#  'instance': 0.5877866649021191,
#  'leave': 0.1823215567939546,
#  'making': 0.0,
#  'understand': 0.25131442828090617,
#  'supposes': 1.2809338454620642,
#  'endeavour': 1.0986122886681098,
#  'properly': 0.5877866649021191,
#  'delicately': 1.2809338454620642,
#  'endeavouring': 0.9444616088408515,
#  'bring': 0.11778303565638346,
#  'worthy': 0.1823215567939546,
#  'employment': 0.8109302162163288,
#  'young': 0.0,
#  'lady': 0.1823215567939546,
#  'imagine': 0.32542240043462795,
#  'planning': 1.5040773967762742,
#  'saying': 0.0,
#  'idle': 0.25131442828090617,
#  'talk': 0.05715841383994862,
#  'merit': 0.6931471805599453,
#  'proud': 0.05715841383994862,
#  'guess': 0.32542240043462795,
#  'known': 0.11778303565638346,
#  'triumph': 0.32542240043462795,
#  'cleverer': 1.791759469228055,
#  'depend': 0.6931471805599453,
#  'merely': 0.4054651081081644,
#  'luck': 0.5877866649021191,
#  'talent': 1.2809338454620642,
#  'word': 0.0,
#  'quarrel': 0.4054651081081644,
#  'claim': 0.6931471805599453,
#  'drawn': 0.4054651081081644,
#  'pictures': 0.32542240043462795,
#  'something': 0.05715841383994862,
#  'nothing': 0.0,
#  'visits': 1.2809338454620642,
#  'given': 0.1823215567939546,
#  'encouragements': 2.1972245773362196,
#  'smoothed': 1.5040773967762742,
#  'matters': 0.1823215567939546,
#  'enough': 0.05715841383994862,
#  'comprehend': 0.6931471805599453,
#  'straightforward': 2.1972245773362196,
#  'open': 0.05715841383994862,
#  'hearted': 0.5877866649021191,
#  'unaffected': 1.0986122886681098,
#  'safely': 0.25131442828090617,
#  'manage': 0.49247648509779424,
#  'likely': 0.32542240043462795,
#  'harm': 0.32542240043462795,
#  'interference': 1.0986122886681098,
#  'rejoined': 0.9444616088408515,
#  'understanding': 0.5877866649021191,
#  'silly': 0.49247648509779424,
#  'break': 0.1823215567939546,
#  'circle': 0.25131442828090617,
#  'grievously': 2.1972245773362196,
#  'elton': 2.8903717578961645,
#  'whole': 0.05715841383994862,
#  'fitted': 0.4054651081081644,
#  'comfortably': 0.49247648509779424,
#  'shame': 0.05715841383994862,
#  'longer': 0.11778303565638346,
#  'joining': 0.8109302162163288,
#  'hands': 0.05715841383994862,
#  'service': 0.4054651081081644,
#  'shew': 0.9444616088408515,
#  'attention': 0.5877866649021191,
#  'ask': 0.05715841383994862,
#  'dare': 0.0,
#  'laughing': 0.25131442828090617,
#  'invite': 0.9444616088408515,
#  'fish': 0.32542240043462795,
#  'chicken': 1.5040773967762742,
#  'chuse': 2.1972245773362196,
#  'six': 0.25131442828090617,
#  'care': 0.05715841383994862,
#  'ii': 0.32542240043462795,
#  'native': 0.6931471805599453,
#  'born': 0.32542240043462795,
#  'respectable': 0.5877866649021191,
#  'generations': 0.8109302162163288,
#  'rising': 0.25131442828090617,
#  'gentility': 1.791759469228055,
#  'property': 0.5877866649021191,
#  'received': 0.4054651081081644,
#  'education': 0.6931471805599453,
#  'succeeding': 1.0986122886681098,
#  'small': 0.11778303565638346,
#  'become': 0.05715841383994862,
#  'indisposed': 1.791759469228055,
#  'homely': 0.9444616088408515,
#  'pursuits': 1.2809338454620642,
#  'brothers': 0.25131442828090617,
#  'engaged': 0.32542240043462795,
#  'satisfied': 0.25131442828090617,
#  'active': 0.6931471805599453,
#  'social': 0.6931471805599453,
#  'entering': 0.6931471805599453,
#  'militia': 1.791759469228055,
#  'county': 0.9444616088408515,
#  'embodied': 1.5040773967762742,
#  'captain': 0.6931471805599453,
#  'general': 0.4054651081081644,
#  'favourite': 0.5877866649021191,
#  'military': 0.6931471805599453,
#  'introduced': 0.6931471805599453,
#  'churchill': 2.1972245773362196,
#  'yorkshire': 1.791759469228055,
#  'fell': 0.05715841383994862,
#  'love': 0.1823215567939546,
#  'surprized': 2.1972245773362196,
#  'except': 0.05715841383994862,
#  'full': 0.0,
#  'pride': 0.1823215567939546,
#  'importance': 0.6931471805599453,
#  'connexion': 1.2809338454620642,
#  'offend': 0.49247648509779424,
#  'command': 0.25131442828090617,
#  'bore': 0.11778303565638346,
#  'proportion': 0.49247648509779424,
#  'estate': 0.4054651081081644,
#  'dissuaded': 2.8903717578961645,
#  'took': 0.1823215567939546,
#  'infinite': 0.5877866649021191,
#  'mortification': 1.5040773967762742,
#  'threw': 0.11778303565638346,
#  'due': 0.32542240043462795,
#  'decorum': 1.2809338454620642,
#  'unsuitable': 2.1972245773362196,
#  'produce': 0.49247648509779424,
#  'ought': 0.11778303565638346,
#  'whose': 0.0,
#  'warm': 0.1823215567939546,
#  'sweet': 0.0,
#  'return': 0.25131442828090617,
#  'goodness': 0.49247648509779424,
#  'spirit': 0.05715841383994862,
#  'resolution': 0.49247648509779424,
#  'pursue': 0.5877866649021191,
#  'refrain': 1.0986122886681098,
#  'unreasonable': 0.8109302162163288,
#  'anger': 0.05715841383994862,
#  'missing': 0.5877866649021191,
#  'luxuries': 2.1972245773362196,
#  'former': 0.1823215567939546,
#  'income': 1.0986122886681098,
#  'still': 0.0,
#  'comparison': 0.5877866649021191,
#  'enscombe': 2.8903717578961645,
#  'cease': 0.25131442828090617,
#  'considered': 0.32542240043462795,
#  'churchills': 2.8903717578961645,
#  'amazing': 1.5040773967762742,
#  'worst': 0.11778303565638346,
#  'bargain': 0.8109302162163288,
#  'poorer': 1.5040773967762742,
#  'child': 0.25131442828090617,
#  'expense': 0.9444616088408515,
#  'relieved': 0.6931471805599453,
#  'boy': 0.05715841383994862,
#  'additional': 0.8109302162163288,
#  'softening': 1.5040773967762742,
#  'lingering': 0.8109302162163288,
#  'illness': 1.0986122886681098,
#  'reconciliation': 0.9444616088408515,
#  'kindred': 1.2809338454620642,
#  'offered': 0.32542240043462795,
#  'charge': 0.1823215567939546,
#  'frank': 1.0986122886681098,
#  'decease': 1.2809338454620642,
#  'scruples': 0.9444616088408515,
#  'reluctance': 1.0986122886681098,
#  'supposed': 0.32542240043462795,
#  'overcome': 0.6931471805599453,
#  'considerations': 1.791759469228055,
#  'wealth': 0.49247648509779424,
#  'seek': 0.1823215567939546,
#  'improve': 0.9444616088408515,
#  'complete': 0.49247648509779424,
#  'became': 0.05715841383994862,
#  'desirable': 0.9444616088408515,
#  'quitted': 0.8109302162163288,
#  'trade': 0.49247648509779424,
#  'established': 0.6931471805599453,
#  'favourable': 0.9444616088408515,
#  'opening': 0.1823215567939546,
#  'concern': 0.49247648509779424,
#  'leisure': 0.5877866649021191,
#  'occupation': 0.6931471805599453,
#  'pleasures': 0.32542240043462795,
#  'eighteen': 0.9444616088408515,
#  'realised': 1.791759469228055,
#  'competence': 2.1972245773362196,
#  'purchase': 0.8109302162163288,
#  'adjoining': 1.0986122886681098,
#  'longed': 0.5877866649021191,
#  'portionless': 2.8903717578961645,
#  'according': 0.25131442828090617,
#  'wishes': 0.6931471805599453,
#  'friendly': 0.32542240043462795,
#  'begun': 0.05715841383994862,
#  'influence': 0.5877866649021191,
#  'schemes': 0.8109302162163288,
#  'tyrannic': 2.1972245773362196,
#  'youth': 0.1823215567939546,
#  'shaken': 0.49247648509779424,
#  'determination': 0.8109302162163288,
#  'settling': 0.8109302162163288,
#  'sale': 1.2809338454620642,
#  'forward': 0.32542240043462795,
#  'steadily': 0.6931471805599453,
#  'objects': 0.49247648509779424,
#  'view': 0.1823215567939546,
#  'accomplished': 0.9444616088408515,
#  'bought': 0.49247648509779424,
#  'obtained': 0.9444616088408515,
#  'beginning': 0.1823215567939546,
#  'new': 0.05715841383994862,
#  'probability': 0.8109302162163288,
#  'greater': 0.1823215567939546,
#  'unhappy': 0.4054651081081644,
#  'secured': 0.9444616088408515,
#  'second': 0.05715841383994862,
#  'delightful': 0.5877866649021191,
#  'judging': 0.6931471805599453,
#  'truly': 0.1823215567939546,
#  'pleasantest': 1.2809338454620642,
#  'proof': 0.5877866649021191,
#  'choose': 0.25131442828090617,
#  'chosen': 0.32542240043462795,
#  'excite': 0.9444616088408515,
#  'choice': 0.25131442828090617,
#  'tacitly': 2.1972245773362196,
#  'heir': 0.6931471805599453,
#  'avowed': 2.1972245773362196,
#  'adoption': 1.2809338454620642,
#  'assume': 0.5877866649021191,
#  'unlikely': 1.2809338454620642,
#  'assistance': 0.8109302162163288,
#  'apprehension': 0.9444616088408515,
#  'aunt': 0.6931471805599453,
#  'capricious': 1.5040773967762742,
#  'governed': 0.9444616088408515,
#  'nature': 0.05715841383994862,
#  'caprice': 0.9444616088408515,
#  'strong': 0.11778303565638346,
#  'affect': 0.6931471805599453,
#  'deservedly': 2.1972245773362196,
#  'saw': 0.0,
#  'report': 0.25131442828090617,
#  'fine': 0.1823215567939546,
#  'sufficiently': 0.5877866649021191,
#  'belonging': 0.9444616088408515,
#  'merits': 0.8109302162163288,
#  'prospects': 1.5040773967762742,
#  'common': 0.05715841383994862,
#  'boasts': 2.1972245773362196,
#  'lively': 0.49247648509779424,
#  'curiosity': 0.4054651081081644,
#  'prevailed': 0.8109302162163288,
#  'compliment': 0.6931471805599453,
#  'achieved': 1.2809338454620642,
#  'generally': 0.4054651081081644,
#  'proposed': 0.6931471805599453,
#  'proper': 0.11778303565638346,
#  'dissentient': 2.8903717578961645,
#  'voice': 0.05715841383994862,
#  'perry': 2.1972245773362196,
#  'drank': 0.6931471805599453,
#  'bates': 2.1972245773362196,
#  'strengthened': 1.5040773967762742,
#  'understood': 0.25131442828090617,
#  'written': 0.1823215567939546,
#  'occasion': 0.32542240043462795,
#  'included': 0.9444616088408515,
#  'mention': 0.4054651081081644,
#  'letter': 0.25131442828090617,
#  'heard': 0.0,
#  'says': 0.4054651081081644,
#  'prized': 1.791759469228055,
#  'course': 0.05715841383994862,
#  'formed': 0.49247648509779424,
#  'pleasing': 0.32542240043462795,
#  'irresistible': 1.0986122886681098,
#  'sense': 0.11778303565638346,
#  'addition': 0.4054651081081644,
#  'source': 0.8109302162163288,
#  'expression': 0.49247648509779424,
#  'congratulation': 1.791759469228055,
#  'fortunate': 1.0986122886681098,
#  'regret': 0.9444616088408515,
#  'partial': 0.5877866649021191,
#  'separation': 0.9444616088408515,
#  'cooled': 1.2809338454620642,
#  'ill': 0.11778303565638346,
#  'missed': 0.5877866649021191,
#  'losing': 0.5877866649021191,
#  'ennui': 1.791759469228055,
#  'companionableness': 2.1972245773362196,
#  'feeble': 0.49247648509779424,
#  'girls': 0.4054651081081644,
#  'energy': 0.6931471805599453,
#  'difficulties': 0.8109302162163288,
#  'privations': 1.791759469228055,
#  'convenient': 0.8109302162163288,
#  'solitary': 0.49247648509779424,
#  'female': 0.5877866649021191,
#  'circumstances': 0.49247648509779424,
#  'approaching': 0.5877866649021191,
#  'season': 0.25131442828090617,
#  'hindrance': 1.791759469228055,
#  'spending': 0.9444616088408515,
#  'evenings': 0.8109302162163288,
#  'week': 0.4054651081081644,
#  'altogether': 0.1823215567939546,
#  'hours': 0.32542240043462795,
#  'moments': 0.6931471805599453,
#  'enjoyment': 0.6931471805599453,
#  'apparent': 0.5877866649021191,
#  'taken': 0.11778303565638346,
#  'surprize': 2.1972245773362196,
#  'centre': 0.5877866649021191,
#  'attended': 0.4054651081081644,
#  'giving': 0.25131442828090617,
#  'stay': 0.1823215567939546,
#  'recovering': 0.8109302162163288,
#  'likelihood': 1.791759469228055,
#  'ceasing': 0.9444616088408515,
#  'weeks': 0.49247648509779424,
#  'alleviation': 2.1972245773362196,
#  'compliments': 1.0986122886681098,
#  'neighbours': 0.8109302162163288,
#  'teased': 2.8903717578961645,
#  'sorrowful': 0.8109302162163288,
#  'cake': 0.8109302162163288,
#  'eat': 0.1823215567939546,
#  'stomach': 0.6931471805599453,
#  'different': 0.25131442828090617,
#  'unwholesome': 2.1972245773362196,
#  'regarded': 0.5877866649021191,
#  'unfit': 1.2809338454620642,
#  'earnestly': 0.4054651081081644,
#  'tried': 0.1823215567939546,
#  ...}

# %% [markdown]
# ### Exercise 2.2
# * Write a function `convert_to_tfidf` that takes two arguments:
#     * a dictionary of documents mapping fileids to documents
#         * where each document is represented as a dictionary or FreqDist {feat:freq})
#     * a dictionary containing idf values
# * and outputs a dictionary of documents where each document is represented as a dictionary or FreqDist with tfidf weights {feat:tfidf}

# %%
def convert_to_tfidf(docs,idfvalues):
    converted={bookid:{f:v*idfvalues.get(f,0) for f,v in doc.items()} for bookid,doc in docs.items()}
    return converted

# %%
def convert_to_tfidf(docs, idfvalues):
    # Create a dictionary to store converted documents
    converted = {}

    # Iterate over each document
    for bookid, doc in docs.items():
        tfidf_doc = {}  # Store TF-IDF for the current document
        
        for feature, tf in doc.items():
            # Calculate TF-IDF for the feature
            idf = idfvalues.get(feature, 0)  # Use 0 if feature not in idfvalues
            tfidf_doc[feature] = tf * idf
        
        # Add the TF-IDF converted document to the result
        converted[bookid] = tfidf_doc

    return converted

# %%
list(book_reps.items())[:3]
# Out:
# [('austen-emma.txt',
#   FreqDist({'mr': 1153, 'emma': 865, 'could': 837, 'would': 820, 'mrs': 699, 'miss': 599, 'must': 567, 'harriet': 506, 'much': 486, 'said': 484, ...})),
#  ('austen-persuasion.txt',
#   FreqDist({'anne': 497, 'could': 451, 'would': 355, 'captain': 303, 'mrs': 291, 'elliot': 289, 'mr': 256, 'one': 238, 'must': 228, 'wentworth': 218, ...})),
#  ('austen-sense.txt',
#   FreqDist({'elinor': 685, 'could': 578, 'marianne': 566, 'mrs': 530, 'would': 515, 'said': 397, 'every': 377, 'one': 331, 'much': 290, 'must': 283, ...}))]

# %%
convert_to_tfidf(book_reps,books_idf)
# Out:
# {'austen-emma.txt': {'emma': 1900.59925939583,
#   'jane': 539.3196002376445,
#   'austen': 1.791759469228055,
#   'volume': 1.4774294552933827,
#   'chapter': 45.41209210811441,
#   'woodhouse': 904.6863602214995,
#   'handsome': 18.714106433716182,
#   'clever': 15.870239952357215,
#   'rich': 0.8002177937592807,
#   'comfortable': 11.06436161477735,
#   'home': 0.0,
#   'happy': 0.0,
#   'disposition': 14.106879957650857,
#   'seemed': 25.707339507947598,
#   'unite': 3.295836866004329,
#   'best': 0.0,
#   'blessings': 5.666769653045109,
#   'existence': 4.7022933192169525,
#   'lived': 6.282860707022654,
#   'nearly': 4.555913606084792,
#   'twenty': 3.533491069691504,
#   'one': 0.0,
#   'years': 10.392328737255411,
#   'world': 0.0,
#   'little': 0.0,
#   'distress': 7.703837054055123,
#   'vex': 0.9444616088408515,
#   'youngest': 2.3511466596084762,
#   'two': 0.0,
#   'daughters': 3.4473353956845596,
#   'affectionate': 7.298371945946959,
#   'indulgent': 2.1972245773362196,
#   'father': 11.831791664869366,
#   'consequence': 8.786404811734954,
#   'sister': 8.293376133269904,
#   'marriage': 14.191278783785753,
#   'mistress': 6.46565331392331,
#   'house': 0.0,
#   'early': 10.303891559517153,
#   'period': 14.596743891893919,
#   'mother': 4.115405796476301,
#   'died': 0.7292862271758184,
#   'long': 0.0,
#   'ago': 8.042061704988997,
#   'indistinct': 1.791759469228055,
#   'remembrance': 4.7022933192169525,
#   'caresses': 1.2809338454620642,
#   'place': 0.0,
#   'supplied': 4.054651081081644,
#   'excellent': 11.06436161477735,
#   'woman': 7.48775221303327,
#   'governess': 16.125835223052494,
#   'fallen': 1.276250897557682,
#   'short': 8.244812495946842,
#   'affection': 20.273255405408218,
#   'sixteen': 8.500154479567664,
#   'miss': 194.92801786034215,
#   'taylor': 86.00445452294665,
#   'mr': 677.7180246321433,
#   'family': 25.057524833466353,
#   'less': 17.08938112310162,
#   'friend': 0.0,
#   'fond': 9.80126270295534,
#   'particularly': 31.884770305757485,
#   'intimacy': 23.070858062030304,
#   'sisters': 4.865581297297973,
#   'even': 33.173504533079615,
#   'ceased': 3.5267199894127144,
#   'hold': 0.8002177937592807,
#   'nominal': 1.791759469228055,
#   'office': 2.9171449087032735,
#   'mildness': 0.8109302162163288,
#   'temper': 6.563576044582366,
#   'hardly': 8.362595531603226,
#   'allowed': 19.699059403911768,
#   'impose': 1.0986122886681098,
#   'restraint': 1.7633599947063572,
#   'shadow': 0.3646431135879092,
#   'authority': 2.4327906486489863,
#   'passed': 17.898232023904537,
#   'away': 0.0,
#   'living': 5.857603207823303,
#   'together': 4.629831521035839,
#   'mutually': 4.512232190328822,
#   'attached': 17.328679513998633,
#   'liked': 6.48744172973063,
#   'highly': 7.81013761043107,
#   'esteeming': 1.791759469228055,
#   'judgment': 31.859756371375184,
#   'directed': 3.5267199894127144,
#   'chiefly': 4.852030263919617,
#   'real': 13.667740818254373,
#   'evils': 9.444616088408516,
#   'indeed': 0.0,
#   'situation': 37.61834655373562,
#   'power': 4.829104461911721,
#   'rather': 8.345128420632498,
#   'much': 27.77898912621503,
#   'way': 0.0,
#   'think': 0.0,
#   'well': 0.0,
#   'disadvantages': 1.791759469228055,
#   'threatened': 3.243720864865315,
#   'alloy': 5.375278407684165,
#   'many': 0.0,
#   'enjoyments': 3.295836866004329,
#   'danger': 3.651274105347887,
#   'however': 42.63033445693626,
#   'present': 10.482690173418128,
#   'unperceived': 3.58351893845611,
#   'means': 15.62027522086214,
#   'rank': 2.9288016039116513,
#   'misfortunes': 1.2809338454620642,
#   'sorrow': 0.2286336553597945,
#   'came': 0.0,
#   'gentle': 1.8845285705021353,
#   'shape': 0.5889151782819173,
#   'disagreeable': 25.618676909241284,
#   'consciousness': 23.070858062030304,
#   'married': 22.16144182940074,
#   'loss': 9.325697486487782,
#   'first': 11.946108492549262,
#   'brought': 0.0,
#   'grief': 2.027325540540822,
#   'wedding': 9.992373303336024,
#   'day': 0.0,
#   'beloved': 5.290079984119071,
#   'sat': 6.74589760137632,
#   'mournful': 1.0986122886681098,
#   'thought': 0.0,
#   'continuance': 3.0081547935525483,
#   'bride': 12.27800091493107,
#   'people': 5.430049314795119,
#   'gone': 0.0,
#   'left': 0.0,
#   'dine': 14.166924132612772,
#   'prospect': 10.542092810812274,
#   'third': 0.9116077839697729,
#   'cheer': 2.772588722239781,
#   'evening': 24.126185114966994,
#   'composed': 4.1588830833596715,
#   'sleep': 0.2355660713127669,
#   'dinner': 8.933756282903776,
#   'usual': 20.678720513516385,
#   'sit': 0.0,
#   'lost': 0.0,
#   'event': 14.106879957650857,
#   'every': 79.30987720537024,
#   'promise': 3.8287526926730466,
#   'happiness': 37.428212867432364,
#   'weston': 1271.7635734743124,
#   'man': 0.0,
#   'unexceptionable': 15.380572041353537,
#   'character': 17.43499964865107,
#   'easy': 7.036803991865373,
#   'fortune': 15.813139216218412,
#   'suitable': 3.777846435363406,
#   'age': 0.0,
#   'pleasant': 2.3434949674378935,
#   'manners': 21.489650729732713,
#   'satisfaction': 11.353023027028602,
#   'considering': 13.862943611198906,
#   'self': 4.1933958062609555,
#   'denying': 5.676511513514301,
#   'generous': 2.3511466596084762,
#   'friendship': 6.534175135303561,
#   'always': 43.392530516961195,
#   'wished': 28.213759915301715,
#   'promoted': 6.016309587105097,
#   'match': 25.94976691892252,
#   'black': 0.9116077839697729,
#   'morning': 0.0,
#   'work': 2.591226784440436,
#   'want': 0.0,
#   'would': 0.0,
#   'felt': 20.602335917716868,
#   'hour': 20.859097547315212,
#   'recalled': 2.1972245773362196,
#   'past': 0.0,
#   'kindness': 27.725887222397812,
#   'taught': 0.40010889687964035,
#   'played': 2.0105154262472493,
#   'five': 13.667740818254373,
#   'old': 0.0,
#   'devoted': 3.4657359027997265,
#   'powers': 4.555913606084792,
#   'attach': 5.493061443340549,
#   'amuse': 10.247470763696514,
#   'health': 9.80126270295534,
#   'nursed': 4.512232190328822,
#   'various': 2.9548589105867653,
#   'illnesses': 8.671115273688493,
#   'childhood': 1.1755733298042381,
#   'large': 4.122406247973421,
#   'debt': 0.5877866649021191,
#   'gratitude': 31.859756371375184,
#   'owing': 2.8333848265225545,
#   'intercourse': 11.333539306090218,
#   'last': 6.801851246953886,
#   'seven': 2.0105154262472493,
#   'equal': 23.11151116216537,
#   'footing': 5.375278407684165,
#   'perfect': 8.54469056155081,
#   'unreserve': 13.183347464017316,
#   'soon': 40.840028721845826,
#   'followed': 3.41570803403512,
#   'isabella': 123.63140337673579,
#   'yet': 0.0,
#   'dearer': 10.75055681536833,
#   'tenderer': 2.1972245773362196,
#   'recollection': 10.247470763696514,
#   'companion': 8.786404811734954,
#   'possessed': 2.4327906486489863,
#   'intelligent': 3.243720864865315,
#   'informed': 4.054651081081644,
#   'useful': 12.3435199629445,
#   'knowing': 6.534175135303561,
#   'ways': 2.9171449087032735,
#   'interested': 12.163953243244931,
#   'concerns': 8.500154479567664,
#   'peculiarly': 10.389077697249366,
#   'pleasure': 6.573217591594092,
#   'scheme': 15.942385152878742,
#   'could': 0.0,
#   'speak': 0.0,
#   'arose': 1.6218604324326575,
#   'never': 65.27111733223575,
#   'find': 8.83372767422876,
#   'fault': 5.026288565618123,
#   'bear': 2.9722375196773285,
#   'change': 7.184765175039391,
#   'true': 3.772455313436609,
#   'going': 0.0,
#   'half': 38.3998432512861,
#   'mile': 3.5796464047809073,
#   'aware': 15.282453287455095,
#   'great': 0.0,
#   'must': 0.0,
#   'difference': 7.790747276708091,
#   'mrs': 566.8402211352138,
#   'advantages': 8.317766166719343,
#   'natural': 21.08418562162455,
#   'domestic': 6.61123126188596,
#   'suffering': 6.48744172973063,
#   'intellectual': 2.8333848265225545,
#   'solitude': 2.0794415416798357,
#   'dearly': 1.1755733298042381,
#   'loved': 10.947557918920438,
#   'meet': 0.0,
#   'conversation': 17.029534540542905,
#   'rational': 12.476649250079015,
#   'playful': 2.5618676909241285,
#   'evil': 10.738939214342722,
#   'actual': 2.4327906486489863,
#   'disparity': 12.542316284596385,
#   'ages': 0.9849529701955885,
#   'increased': 7.053439978825429,
#   'constitution': 7.690286020676768,
#   'habits': 8.317766166719343,
#   'valetudinarian': 2.8903717578961645,
#   'life': 0.0,
#   'without': 0.0,
#   'activity': 3.243720864865315,
#   'mind': 15.076228564017082,
#   'body': 22.732125881682006,
#   'older': 2.6033792034770236,
#   'though': 0.0,
#   'everywhere': 1.7633599947063572,
#   'friendliness': 3.295836866004329,
#   'heart': 3.772455313436609,
#   'amiable': 28.382557567571506,
#   'talents': 10.247470763696514,
#   'recommended': 9.887510598012987,
#   'time': 0.0,
#   'comparatively': 1.888923217681703,
#   'removed': 3.2542240043462796,
#   'matrimony': 14.33407575382444,
#   'settled': 9.80126270295534,
#   'london': 18.245929864867396,
#   'miles': 6.892906837838795,
#   'beyond': 9.845364066873548,
#   'daily': 5.877866649021191,
#   'reach': 1.276250897557682,
#   'october': 5.123735381848257,
#   'november': 5.493061443340549,
#   'struggled': 1.1755733298042381,
#   'hartfield': 462.45948126338635,
#   'christmas': 6.46565331392331,
#   'next': 0.0,
#   'visit': 15.679653884280095,
#   'husband': 11.06436161477735,
#   'children': 0.0,
#   'fill': 0.2355660713127669,
#   'give': 28.98912753023878,
#   'society': 23.638871284694122,
#   'highbury': 361.2964697370206,
#   'populous': 2.1972245773362196,
#   'village': 0.9849529701955885,
#   'almost': 5.029940417915479,
#   'amounting': 1.791759469228055,
#   'town': 7.484715209996443,
#   'spite': 6.031546278741748,
#   'separate': 5.909717821173531,
#   'lawn': 5.123735381848257,
#   'shrubberies': 3.0081547935525483,
#   'name': 3.200871175037123,
#   'really': 62.03616154054915,
#   'belong': 6.0819766216224656,
#   'afforded': 8.788898309344878,
#   'equals': 0.9444616088408515,
#   'woodhouses': 11.561487031584658,
#   'looked': 29.613438439551143,
#   'acquaintance': 51.088603621628714,
#   'universally': 5.123735381848257,
#   'civil': 7.641226643727547,
#   'among': 0.0,
#   'accepted': 5.877866649021191,
#   'lieu': 2.1972245773362196,
#   'melancholy': 5.909717821173531,
#   'sigh': 2.237877677471286,
#   'wish': 0.0,
#   'impossible': 13.342318417819746,
#   'things': 3.5438216580768147,
#   'till': 0.0,
#   'awoke': 0.8109302162163288,
#   'made': 0.0,
#   'necessary': 14.596743891893919,
#   'cheerful': 9.43724961260421,
#   'spirits': 11.668579634813094,
#   'required': 8.229013308629668,
#   'support': 3.939811880782354,
#   'nervous': 8.920232378379616,
#   'easily': 2.552501795115364,
#   'depressed': 6.591673732008658,
#   'used': 9.116077839697729,
#   'hating': 2.1972245773362196,
#   'part': 0.0,
#   'kind': 9.658208923823443,
#   'origin': 2.3511466596084762,
#   'reconciled': 6.48744172973063,
#   'daughter': 11.303936521225184,
#   'marrying': 33.30427998201367,
#   'ever': 35.188060461233235,
#   'compassion': 10.542092810812274,
#   'entirely': 19.206582918813975,
#   'obliged': 44.67178653256105,
#   'selfishness': 3.777846435363406,
#   'able': 18.094638836225243,
#   'suppose': 20.3564686907534,
#   'feel': 17.320547895425687,
#   'differently': 10.389077697249366,
#   'disposed': 14.556090791758852,
#   'done': 0.0,
#   'sad': 4.5580389198488644,
#   'thing': 0.0,
#   'deal': 29.93886083998577,
#   'happier': 7.6246189861593985,
#   'spent': 6.8338704091271865,
#   'rest': 2.857920691997431,
#   'smiled': 4.272345280775405,
#   'chatted': 2.1972245773362196,
#   'cheerfully': 3.939811880782354,
#   'keep': 3.886840176660654,
#   'thoughts': 4.475755354942572,
#   'tea': 18.714973875118524,
#   'say': 0.0,
#   'exactly': 14.576236840292557,
#   'said': 0.0,
#   'poor': 7.773544282233012,
#   'pity': 6.534175135303561,
#   'cannot': 0.0,
#   'agree': 7.387147276466914,
#   'papa': 49.63455409361705,
#   'know': 0.0,
#   'good': 0.0,
#   'humoured': 5.666769653045109,
#   'thoroughly': 13.16979643063896,
#   'deserves': 4.865581297297973,
#   'wife': 12.397865861988912,
#   'live': 3.099466465497228,
#   'us': 26.436625735123418,
#   'odd': 8.460982411300327,
#   'humours': 2.5618676909241285,
#   'might': 0.0,
#   'advantage': 10.947557918920438,
#   'three': 4.115405796476301,
#   'times': 0.0,
#   'dear': 43.939495187343056,
#   'often': 5.201415659435325,
#   'shall': 12.403375803268851,
#   'see': 0.0,
#   'coming': 16.226618554661957,
#   'meeting': 4.593538390598955,
#   'begin': 3.651274105347887,
#   'go': 0.0,
#   'pay': 2.9445758914095865,
#   'get': 3.829613727276558,
#   'far': 8.244812495946842,
#   'randalls': 260.1334582106548,
#   'distance': 6.282860707022654,
#   'walk': 3.200871175037123,
#   'nobody': 29.598952891896,
#   'walking': 2.572128622797688,
#   'carriage': 33.9808774717478,
#   'sure': 11.660316423349519,
#   'james': 20.873633484694086,
#   'like': 0.0,
#   'put': 0.0,
#   'horses': 2.9445758914095865,
#   'paying': 7.6246189861593985,
#   'stable': 1.6218604324326575,
#   'already': 5.300236604537256,
#   'talked': 32.50344801645442,
#   'night': 0.0,
#   'may': 0.0,
#   'housemaid': 1.791759469228055,
#   'doubt': 0.0,
#   'whether': 3.658138485756712,
#   'take': 0.0,
#   'anywhere': 7.879623761564708,
#   'else': 0.0,
#   'got': 2.0577028982381504,
#   'hannah': 4.394449154672439,
#   'mentioned': 12.80438861254265,
#   'glad': 2.857920691997431,
#   'lucky': 5.877866649021191,
#   'slighted': 7.685603072772386,
#   'upon': 39.95899409666408,
#   'account': 14.827551268573464,
#   'make': 0.0,
#   'servant': 3.5267199894127144,
#   'pretty': 12.397865861988912,
#   'spoken': 7.790747276708091,
#   'girl': 15.294852820427513,
#   'opinion': 12.944830532370776,
#   'whenever': 9.111827212169583,
#   'curtseys': 2.8903717578961645,
#   'asks': 3.842801536386193,
#   'manner': 18.848582121067963,
#   'needlework': 2.1972245773362196,
#   'observe': 13.519093292748739,
#   'turns': 2.9288016039116513,
#   'lock': 0.4054651081081644,
#   'door': 8.569113169315866,
#   'right': 5.258574073275273,
#   'bangs': 2.8903717578961645,
#   'comfort': 7.655897317664925,
#   'somebody': 4.021030852494499,
#   'goes': 0.3429504830396917,
#   'hearing': 1.829069242878356,
#   'tell': 0.0,
#   'spared': 6.61123126188596,
#   'exertions': 6.591673732008658,
#   'maintain': 4.394449154672439,
#   'flow': 2.9548589105867653,
#   'ideas': 12.97488345946126,
#   'hoped': 21.17648885920515,
#   'help': 9.80126270295534,
#   'backgammon': 8.671115273688493,
#   'tolerably': 14.166924132612772,
#   'attacked': 2.1972245773362196,
#   'regrets': 9.024464380657644,
#   'table': 3.1801419627223533,
#   'placed': 4.881336006519419,
#   'visitor': 9.887510598012987,
#   'immediately': 12.762508975576822,
#   'afterwards': 10.303891559517153,
#   'walked': 13.068350270607121,
#   'unnecessary': 6.48744172973063,
#   'knightley': 1124.354613821608,
#   'sensible': 10.136627702704109,
#   'eight': 1.7592009979663432,
#   'thirty': 1.6271120021731398,
#   'intimate': 9.444616088408516,
#   'connected': 7.6246189861593985,
#   'elder': 1.6218604324326575,
#   'brother': 6.47806696110109,
#   'frequent': 6.48744172973063,
#   'welcome': 2.9171449087032735,
#   'directly': 9.298399396491684,
#   'mutual': 4.054651081081644,
#   'connexions': 17.91759469228055,
#   'returned': 15.813139216218412,
#   'late': 1.5432771736786128,
#   'days': 9.116077839697729,
#   'absence': 3.7697164242135925,
#   'brunswick': 31.79408933685781,
#   'square': 4.865581297297973,
#   'circumstance': 27.57162735135518,
#   'animated': 4.722308044204258,
#   'inquiries': 10.986122886681098,
#   'answered': 4.011074249467001,
#   'satisfactorily': 4.394449154672439,
#   'gratefully': 4.722308044204258,
#   'observed': 12.93130662784662,
#   'come': 0.0,
#   'call': 0.0,
#   'afraid': 11.850901191607049,
#   'shocking': 5.666769653045109,
#   'sir': 12.033222748401004,
#   'beautiful': 7.81013761043107,
#   'moonlight': 1.6218604324326575,
#   'mild': 2.3511466596084762,
#   'draw': 0.5715841383994862,
#   'back': 0.0,
#   'fire': 0.914534621439178,
#   'found': 0.0,
#   'damp': 4.865581297297973,
#   'dirty': 4.1588830833596715,
#   'catch': 1.6489624991893683,
#   'cold': 3.0865543473572257,
#   'look': 0.0,
#   'shoes': 2.772588722239781,
#   'speck': 1.791759469228055,
#   'quite': 16.11867270286551,
#   'surprising': 1.888923217681703,
#   'vast': 4.1588830833596715,
#   'rain': 7.159292809561815,
#   'rained': 1.2809338454620642,
#   'dreadfully': 7.555692870726812,
#   'hard': 0.6859009660793834,
#   'breakfast': 7.053439978825429,
#   'wanted': 18.848582121067963,
#   'bye': 8.317766166719343,
#   'joy': 5.857603207823303,
#   'sort': 20.420014360922913,
#   'feeling': 6.595849996757473,
#   'hurry': 9.731162594595945,
#   'congratulations': 15.380572041353537,
#   'hope': 8.173653179112653,
#   'went': 0.0,
#   'behave': 2.0794415416798357,
#   'cried': 4.629831521035839,
#   'ah': 5.653585711506405,
#   'tis': 0.9849529701955885,
#   'business': 13.82229355544984,
#   'please': 0.0,
#   'possibly': 5.532180807388675,
#   'regard': 10.806520416078966,
#   'comes': 2.8267928557532027,
#   'question': 2.2291781397579964,
#   'dependence': 14.090272300082706,
#   'independence': 12.084735175349207,
#   'rate': 5.857603207823303,
#   'better': 9.888405594311111,
#   'especially': 6.282860707022654,
#   'fanciful': 3.842801536386193,
#   'troublesome': 7.298371945946959,
#   'creature': 7.1105407149642295,
#   'playfully': 3.58351893845611,
#   'head': 0.0,
#   'certainly': 32.86766244389742,
#   'believe': 25.63407168465243,
#   'sometimes': 4.593538390598955,
#   'dearest': 11.755733298042381,
#   'mean': 6.949199103726624,
#   'horrible': 2.027325540540822,
#   'idea': 32.5422400434628,
#   'oh': 11.031573871110083,
#   'meant': 5.064670533224489,
#   'loves': 2.9288016039116513,
#   'joke': 4.1588830833596715,
#   'another': 0.0,
#   'fact': 6.031546278741748,
#   'faults': 5.417241336075737,
#   'told': 0.0,
#   'agreeable': 64.04669227310322,
#   'knew': 5.029940417915479,
#   'suspect': 14.556090791758852,
#   'knows': 9.762672013038838,
#   'flatter': 3.4657359027997265,
#   'reflection': 5.857603207823303,
#   'persons': 3.5796464047809073,
#   'chances': 5.493061443340549,
#   'gainer': 1.791759469228055,
#   'willing': 2.3701802383214097,
#   'let': 0.0,
#   'pass': 8.042061704988997,
#   'hear': 11.778303565638346,
#   'behaved': 10.389077697249366,
#   'charmingly': 8.788898309344878,
#   'punctual': 1.0986122886681098,
#   'looks': 9.43724961260421,
#   'tear': 1.3016896017385118,
#   'face': 0.0,
#   'seen': 4.172564210316249,
#   'apart': 0.9762672013038838,
#   'bears': 1.1755733298042381,
#   'sorry': 7.184765175039391,
#   'lose': 3.4641095790851373,
#   'thinks': 11.326959157249268,
#   'turned': 7.2881184201462785,
#   'divided': 1.969905940391177,
#   'tears': 2.2618298545281554,
#   'smiles': 6.0819766216224656,
#   'acceptable': 8.788898309344878,
#   'important': 5.026288565618123,
#   'secure': 4.432288365880148,
#   'provision': 3.295836866004329,
#   'therefore': 3.5438216580768147,
#   'allow': 11.81177812920259,
#   'pain': 13.78581367567759,
#   'happily': 10.580159968238142,
#   'forgotten': 3.4641095790851373,
#   'matter': 1.829069242878356,
#   'considerable': 11.78350206951907,
#   'four': 9.762672013038838,
#   'proved': 6.48744172973063,
#   'marry': 31.026018561161038,
#   'shook': 2.0105154262472493,
#   'fondly': 5.123735381848257,
#   'replied': 32.03174354054499,
#   'matches': 7.685603072772386,
#   'foretell': 3.0081547935525483,
#   'whatever': 6.508448008692559,
#   'pray': 1.4861187598386643,
#   'none': 0.0,
#   'greatest': 11.758488135136767,
#   'amusement': 15.111385741453624,
#   'success': 5.417241336075737,
#   'widower': 3.0081547935525483,
#   'perfectly': 16.838066694820714,
#   'constantly': 3.939811880782354,
#   'occupied': 11.090354888959125,
#   'either': 3.658138485756712,
#   'friends': 4.686989934875787,
#   'wherever': 2.277956803042396,
#   'need': 4.946887497568105,
#   'spend': 8.864576731760296,
#   'single': 3.4641095790851373,
#   'year': 7.036803991865373,
#   'alone': 0.0,
#   'deathbed': 2.1972245773362196,
#   'others': 3.4295048303969176,
#   'son': 8.569113169315866,
#   'uncle': 15.942385152878742,
#   'letting': 1.4774294552933827,
#   'solemn': 1.6271120021731398,
#   'nonsense': 9.849529701955884,
#   'subject': 39.33011548649195,
#   'believed': 18.651394972975563,
#   'since': 3.7152968995966607,
#   'met': 0.0,
#   'broadway': 1.791759469228055,
#   'lane': 6.46565331392331,
#   'began': 3.658138485756712,
#   'drizzle': 2.8903717578961645,
#   'darted': 2.4327906486489863,
#   'gallantry': 15.371206145544772,
#   'borrowed': 1.3862943611198906,
#   'umbrellas': 3.58351893845611,
#   'farmer': 6.238324625039508,
#   'mitchell': 2.8903717578961645,
#   'planned': 1.888923217681703,
#   'blessed': 2.277956803042396,
#   'instance': 5.290079984119071,
#   'leave': 10.574650294049366,
#   'making': 0.0,
#   'understand': 17.08938112310162,
#   'supposes': 1.2809338454620642,
#   'endeavour': 15.380572041353537,
#   'properly': 5.877866649021191,
#   'delicately': 1.2809338454620642,
#   'endeavouring': 2.8333848265225545,
#   'bring': 4.475755354942572,
#   'worthy': 3.281788022291183,
#   'employment': 8.109302162163289,
#   'young': 0.0,
#   'lady': 13.309473645958684,
#   'imagine': 17.898232023904537,
#   'planning': 4.512232190328822,
#   'saying': 0.0,
#   'idle': 1.0052577131236247,
#   'talk': 3.4295048303969176,
#   'merit': 9.704060527839234,
#   'proud': 0.457267310719589,
#   'guess': 8.1355600108657,
#   'known': 7.066982139383008,
#   'triumph': 1.9525344026077676,
#   'cleverer': 5.375278407684165,
#   'depend': 18.021826694558577,
#   'merely': 11.758488135136767,
#   'luck': 6.46565331392331,
#   'talent': 11.528404609158578,
#   'word': 0.0,
#   'quarrel': 4.460116189189808,
#   'claim': 8.317766166719343,
#   'drawn': 6.0819766216224656,
#   'pictures': 0.6508448008692559,
#   'something': 6.458900763914194,
#   'nothing': 0.0,
#   'visits': 17.9330738364689,
#   'given': 14.038759873134504,
#   'encouragements': 2.1972245773362196,
#   'smoothed': 3.0081547935525483,
#   'matters': 1.8232155679395459,
#   'enough': 7.373435385353372,
#   'comprehend': 10.39720770839918,
#   'straightforward': 6.591673732008658,
#   'open': 2.3434949674378935,
#   'hearted': 7.641226643727547,
#   'unaffected': 4.394449154672439,
#   'safely': 4.774974137337217,
#   'manage': 2.462382425488971,
#   'likely': 14.969430419992886,
#   'harm': 4.230491205650163,
#   'interference': 8.788898309344878,
#   'rejoined': 1.888923217681703,
#   'understanding': 16.458026617259335,
#   'silly': 5.909717821173531,
#   'break': 2.3701802383214097,
#   'circle': 4.523659709056311,
#   'grievously': 2.1972245773362196,
#   'elton': 1112.7931267900233,
#   'whole': 4.344039451836095,
#   'fitted': 0.4054651081081644,
#   'comfortably': 5.417241336075737,
#   'shame': 0.5144257245595376,
#   'longer': 6.949199103726624,
#   'joining': 1.6218604324326575,
#   'hands': 1.3146435183188183,
#   'service': 9.325697486487782,
#   'shew': 26.44492504754384,
#   'attention': 34.67941322922503,
#   'ask': 2.4578117951177907,
#   'dare': 0.0,
#   'laughing': 4.272345280775405,
#   'invite': 12.27800091493107,
#   'fish': 0.6508448008692559,
#   'chicken': 3.0081547935525483,
#   'chuse': 52.733389856069266,
#   'six': 3.015773139370874,
#   'care': 2.9150791058373797,
#   'ii': 1.3016896017385118,
#   'native': 3.4657359027997265,
#   'born': 1.9525344026077676,
#   'respectable': 11.755733298042381,
#   'generations': 1.6218604324326575,
#   'rising': 1.507886569685437,
#   'gentility': 10.75055681536833,
#   'property': 3.5267199894127144,
#   'received': 14.596743891893919,
#   'education': 11.090354888959125,
#   'succeeding': 5.493061443340549,
#   'small': 3.651274105347887,
#   'become': 0.6859009660793834,
#   'indisposed': 5.375278407684165,
#   'homely': 0.9444616088408515,
#   'pursuits': 2.5618676909241285,
#   'brothers': 1.0052577131236247,
#   'engaged': 12.366051216515862,
#   'satisfied': 13.068350270607121,
#   'active': 4.852030263919617,
#   'social': 4.1588830833596715,
#   'entering': 5.545177444479562,
#   'militia': 3.58351893845611,
#   'county': 1.888923217681703,
#   'embodied': 1.5040773967762742,
#   'captain': 2.0794415416798357,
#   'general': 26.355232027030684,
#   'favourite': 13.519093292748739,
#   'military': 0.6931471805599453,
#   'introduced': 5.545177444479562,
#   'churchill': 492.17830532331317,
#   'yorkshire': 14.33407575382444,
#   'fell': 0.5715841383994862,
#   'love': 21.331622144892687,
#   'surprized': 70.31118647475903,
#   'except': 1.829069242878356,
#   'full': 0.0,
#   'pride': 3.281788022291183,
#   'importance': 8.317766166719343,
#   'connexion': 25.618676909241284,
#   'offend': 1.4774294552933827,
#   'command': 5.528917422179935,
#   'bore': 0.8244812495946842,
#   'proportion': 1.969905940391177,
#   'estate': 1.6218604324326575,
#   'dissuaded': 2.8903717578961645,
#   'took': 8.569113169315866,
#   'infinite': 1.7633599947063572,
#   'mortification': 16.544851364539017,
#   'threw': 0.2355660713127669,
#   'due': 7.484715209996443,
#   'decorum': 2.5618676909241285,
#   'unsuitable': 6.591673732008658,
#   'produce': 4.924764850977942,
#   'ought': 11.189388387356429,
#   'whose': 0.0,
#   'warm': 5.469646703818638,
#   'sweet': 0.0,
#   'return': 14.073607983730746,
#   'goodness': 3.4473353956845596,
#   'spirit': 1.5432771736786128,
#   'resolution': 15.26677103803162,
#   'pursue': 0.5877866649021191,
#   'refrain': 5.493061443340549,
#   'unreasonable': 7.298371945946959,
#   'anger': 0.40010889687964035,
#   'missing': 1.7633599947063572,
#   'luxuries': 2.1972245773362196,
#   'former': 2.552501795115364,
#   'income': 10.986122886681098,
#   'still': 0.0,
#   'comparison': 6.46565331392331,
#   'enscombe': 104.05338328426193,
#   'cease': 1.7592009979663432,
#   'considered': 6.183025608257931,
#   'churchills': 43.35557636844247,
#   'amazing': 6.016309587105097,
#   'worst': 2.237877677471286,
#   'bargain': 1.6218604324326575,
#   'poorer': 1.5040773967762742,
#   'child': 9.549948274674435,
#   'expense': 6.61123126188596,
#   'relieved': 3.4657359027997265,
#   'boy': 0.7430593799193321,
#   'additional': 3.243720864865315,
#   'softening': 3.0081547935525483,
#   'lingering': 0.8109302162163288,
#   'illness': 9.887510598012987,
#   'reconciliation': 2.8333848265225545,
#   'kindred': 1.2809338454620642,
#   'offered': 2.6033792034770236,
#   'charge': 3.281788022291183,
#   'frank': 228.51135604296684,
#   'decease': 2.5618676909241285,
#   'scruples': 9.444616088408516,
#   'reluctance': 3.295836866004329,
#   'supposed': 11.389784015211978,
#   'overcome': 6.238324625039508,
#   'considerations': 3.58351893845611,
#   'wealth': 3.4473353956845596,
#   'seek': 1.0939293407637276,
#   'improve': 6.61123126188596,
#   'complete': 9.849529701955884,
#   'became': 1.3146435183188183,
#   'desirable': 17.000308959135328,
#   'quitted': 7.298371945946959,
#   'trade': 3.4473353956845596,
#   'established': 3.4657359027997265,
#   'favourable': 13.22246252377192,
#   'opening': 2.734823351909319,
#   'concern': 8.864576731760296,
#   'leisure': 7.641226643727547,
#   'occupation': 2.772588722239781,
#   'pleasures': 2.9288016039116513,
#   'eighteen': 3.777846435363406,
#   'realised': 3.58351893845611,
#   'competence': 2.1972245773362196,
#   'purchase': 4.865581297297973,
#   'adjoining': 6.591673732008658,
#   'longed': 3.5267199894127144,
#   'portionless': 2.8903717578961645,
#   'according': 1.2565721414045308,
#   'wishes': 13.862943611198906,
#   'friendly': 5.857603207823303,
#   'begun': 0.6859009660793834,
#   'influence': 14.106879957650857,
#   'schemes': 5.676511513514301,
#   'tyrannic': 2.1972245773362196,
#   'youth': 2.0055371247335003,
#   'shaken': 2.9548589105867653,
#   'determination': 4.054651081081644,
#   'settling': 3.243720864865315,
#   'sale': 2.5618676909241285,
#   'forward': 11.715206415646605,
#   'steadily': 3.4657359027997265,
#   'objects': 3.4473353956845596,
#   'view': 4.922682033436774,
#   'accomplished': 10.389077697249366,
#   'bought': 1.969905940391177,
#   'obtained': 4.722308044204258,
#   'beginning': 7.2928622717581835,
#   'new': 2.0577028982381504,
#   'probability': 9.731162594595945,
#   'greater': 5.287325147024683,
#   'unhappy': 7.703837054055123,
#   'secured': 10.389077697249366,
#   'second': 1.7719108290384074,
#   'delightful': 24.09925326098688,
#   'judging': 7.6246189861593985,
#   'truly': 2.187858681527455,
#   'pleasantest': 3.842801536386193,
#   'proof': 13.519093292748739,
#   'choose': 0.25131442828090617,
#   'chosen': 4.881336006519419,
#   'excite': 2.8333848265225545,
#   'choice': 2.2618298545281554,
#   'tacitly': 4.394449154672439,
#   'heir': 2.0794415416798357,
#   'avowed': 2.1972245773362196,
#   'adoption': 1.2809338454620642,
#   'assume': 0.5877866649021191,
#   'unlikely': 5.123735381848257,
#   'assistance': 11.353023027028602,
#   'apprehension': 6.61123126188596,
#   'aunt': 39.50938929191688,
#   'capricious': 1.5040773967762742,
#   'governed': 1.888923217681703,
#   'nature': 2.3434949674378935,
#   'caprice': 2.8333848265225545,
#   'strong': 5.182453568880872,
#   'affect': 3.4657359027997265,
#   'deservedly': 4.394449154672439,
#   'saw': 0.0,
#   'report': 2.5131442828090615,
#   'fine': 7.657505385346093,
#   'sufficiently': 5.290079984119071,
#   'belonging': 3.777846435363406,
#   'merits': 5.676511513514301,
#   'prospects': 12.032619174210193,
#   'common': 2.0005444843982017,
#   'boasts': 2.1972245773362196,
#   'lively': 5.909717821173531,
#   'curiosity': 11.353023027028602,
#   'prevailed': 4.865581297297973,
#   'compliment': 21.487562597358306,
#   'achieved': 2.5618676909241285,
#   'generally': 9.731162594595945,
#   'proposed': 9.704060527839234,
#   'proper': 4.946887497568105,
#   'dissentient': 2.8903717578961645,
#   'voice': 2.6864454504775854,
#   'perry': 175.77796618689757,
#   'drank': 1.3862943611198906,
#   'bates': 325.1892374457605,
#   'strengthened': 6.016309587105097,
#   'understood': 5.780231850460842,
#   'written': 4.37571736305491,
#   'occasion': 9.111827212169583,
#   'included': 4.722308044204258,
#   'mention': 7.703837054055123,
#   'letter': 27.393272682618772,
#   'heard': 0.0,
#   'says': 12.569418351353097,
#   'prized': 1.791759469228055,
#   'course': 3.486663244236866,
#   'formed': 5.909717821173531,
#   'pleasing': 7.159292809561815,
#   'irresistible': 5.493061443340549,
#   'sense': 6.595849996757473,
#   'addition': 4.054651081081644,
#   'source': 5.676511513514301,
#   'expression': 4.432288365880148,
#   'congratulation': 3.58351893845611,
#   'fortunate': 29.662531794038966,
#   'regret': 24.55600182986214,
#   'partial': 4.114506654314834,
#   'separation': 3.777846435363406,
#   'cooled': 2.5618676909241285,
#   'ill': 8.598161602915992,
#   'missed': 4.7022933192169525,
#   'losing': 2.9389333245105953,
#   'ennui': 1.791759469228055,
#   'companionableness': 2.1972245773362196,
#   'feeble': 0.49247648509779424,
#   'girls': 5.271046405406137,
#   'energy': 2.0794415416798357,
#   'difficulties': 13.78581367567759,
#   'privations': 7.16703787691222,
#   'convenient': 4.054651081081644,
#   'solitary': 1.4774294552933827,
#   'female': 4.114506654314834,
#   'circumstances': 15.26677103803162,
#   'approaching': 4.114506654314834,
#   'season': 1.507886569685437,
#   'hindrance': 1.791759469228055,
#   'spending': 4.722308044204258,
#   'evenings': 4.054651081081644,
#   'week': 11.758488135136767,
#   'altogether': 4.1933958062609555,
#   'hours': 8.1355600108657,
#   'moments': 8.317766166719343,
#   'enjoyment': 15.249237972318797,
#   'apparent': 5.877866649021191,
#   'taken': 6.83141606807024,
#   'surprize': 81.29730936144013,
#   'centre': 1.7633599947063572,
#   'attended': 3.6491859729734797,
#   'giving': 11.560463700921684,
#   'stay': 8.022148498934001,
#   'recovering': 3.243720864865315,
#   'likelihood': 3.58351893845611,
#   'ceasing': 0.9444616088408515,
#   'weeks': 10.342006187053679,
#   'alleviation': 4.394449154672439,
#   'compliments': 16.479184330021646,
#   'neighbours': 12.97488345946126,
#   'teased': 2.8903717578961645,
#   'sorrowful': 4.054651081081644,
#   'cake': 6.48744172973063,
#   'eat': 2.187858681527455,
#   'stomach': 1.3862943611198906,
#   'different': 10.55520598779806,
#   'unwholesome': 10.986122886681098,
#   'regarded': 2.3511466596084762,
#   'unfit': 5.123735381848257,
#   'earnestly': 4.865581297297973,
#   'tried': 4.740360476642819,
#   ...},
#  'austen-persuasion.txt': {'persuasion': 6.61123126188596,
#   'jane': 1.791759469228055,
#   'austen': 1.791759469228055,
#   'chapter': 19.46232518919189,
#   'sir': 27.165911962299234,
#   'walter': 212.07491294545466,
#   'elliot': 835.3174380319915,
#   'kellynch': 210.99713832642,
#   'hall': 5.105003590230728,
#   'somersetshire': 8.788898309344878,
#   'man': 0.0,
#   'amusement': 9.444616088408516,
#   'never': 28.259841303062963,
#   'took': 3.4641095790851373,
#   'book': 1.4585724543516367,
#   'baronetage': 5.780743515792329,
#   'found': 0.0,
#   'occupation': 3.4657359027997265,
#   'idle': 0.7539432848427186,
#   'hour': 8.293376133269904,
#   'consolation': 2.772588722239781,
#   'distressed': 4.865581297297973,
#   'one': 0.0,
#   'faculties': 0.9444616088408515,
#   'roused': 8.788898309344878,
#   'admiration': 5.877866649021191,
#   'respect': 3.099466465497228,
#   'contemplating': 1.0986122886681098,
#   'limited': 2.1972245773362196,
#   'remnant': 1.2809338454620642,
#   'earliest': 2.772588722239781,
#   'patents': 2.1972245773362196,
#   'unwelcome': 2.8333848265225545,
#   'sensations': 9.887510598012987,
#   'arising': 2.1972245773362196,
#   'domestic': 10.389077697249366,
#   'affairs': 4.7022933192169525,
#   'changed': 1.4585724543516367,
#   'naturally': 4.1588830833596715,
#   'pity': 3.2670875676517803,
#   'contempt': 2.9389333245105953,
#   'turned': 5.27760299389903,
#   'almost': 3.4295048303969176,
#   'endless': 0.5877866649021191,
#   'creations': 3.0081547935525483,
#   'last': 5.029940417915479,
#   'century': 0.9444616088408515,
#   'every': 18.596798792983368,
#   'leaf': 0.49247648509779424,
#   'powerless': 1.5040773967762742,
#   'could': 0.0,
#   'read': 0.7430593799193321,
#   'history': 6.48744172973063,
#   'interest': 17.43499964865107,
#   'failed': 3.5267199894127144,
#   'page': 1.1755733298042381,
#   'favourite': 4.7022933192169525,
#   'volume': 1.969905940391177,
#   'always': 20.055371247335007,
#   'opened': 2.5131442828090615,
#   'born': 1.9525344026077676,
#   'march': 0.1823215567939546,
#   'married': 11.819435642347061,
#   'july': 2.5618676909241285,
#   'elizabeth': 114.00311224612372,
#   'daughter': 4.1933958062609555,
#   'james': 6.591673732008658,
#   'stevenson': 2.8903717578961645,
#   'esq': 7.520386983881371,
#   'south': 0.5026288565618123,
#   'park': 2.772588722239781,
#   'county': 3.777846435363406,
#   'gloucester': 2.8903717578961645,
#   'lady': 39.381456267494194,
#   'died': 1.276250897557682,
#   'issue': 0.49247648509779424,
#   'june': 3.842801536386193,
#   'anne': 469.3974195939032,
#   'august': 2.1972245773362196,
#   'still': 0.0,
#   'son': 3.099466465497228,
#   'november': 9.887510598012987,
#   'mary': 95.65431091727245,
#   'precisely': 3.5267199894127144,
#   'paragraph': 3.0081547935525483,
#   'originally': 3.295836866004329,
#   'stood': 0.0,
#   'printer': 1.791759469228055,
#   'hands': 1.1431682767989724,
#   'improved': 11.353023027028602,
#   'adding': 3.243720864865315,
#   'information': 4.865581297297973,
#   'family': 26.033792034770237,
#   'words': 2.7090098200968193,
#   'date': 2.4327906486489863,
#   'birth': 3.2542240043462796,
#   'december': 1.0986122886681098,
#   'charles': 249.67684786486151,
#   'heir': 9.010913347279288,
#   'musgrove': 375.7483285265014,
#   'uppercross': 222.55862535800466,
#   'somerset': 3.58351893845611,
#   'inserting': 2.1972245773362196,
#   'accurately': 1.2809338454620642,
#   'day': 0.0,
#   'month': 4.432288365880148,
#   'lost': 0.0,
#   'wife': 8.204470055727956,
#   'followed': 1.766745534845752,
#   'rise': 0.0,
#   'ancient': 0.7539432848427186,
#   'respectable': 2.9389333245105953,
#   'usual': 8.920232378379616,
#   'terms': 8.864576731760296,
#   'first': 6.458900763914194,
#   'settled': 5.528917422179935,
#   'cheshire': 1.791759469228055,
#   'mentioned': 6.402194306271325,
#   'dugdale': 2.8903717578961645,
#   'serving': 1.0986122886681098,
#   'office': 0.9116077839697729,
#   'high': 0.0,
#   'sheriff': 2.1972245773362196,
#   'representing': 2.5618676909241285,
#   'borough': 2.8903717578961645,
#   'three': 2.3434949674378935,
#   'successive': 3.0081547935525483,
#   'parliaments': 2.1972245773362196,
#   'exertions': 4.394449154672439,
#   'loyalty': 1.0986122886681098,
#   'dignity': 4.460116189189808,
#   'baronet': 19.709354161508603,
#   'year': 6.785489563584466,
#   'ii': 0.32542240043462795,
#   'marys': 2.8903717578961645,
#   'elizabeths': 2.8903717578961645,
#   'forming': 3.243720864865315,
#   'altogether': 2.3701802383214097,
#   'two': 0.0,
#   'handsome': 9.357053216858091,
#   'duodecimo': 2.1972245773362196,
#   'pages': 0.8109302162163288,
#   'concluding': 2.1972245773362196,
#   'arms': 1.4585724543516367,
#   'motto': 2.1972245773362196,
#   'principal': 5.545177444479562,
#   'seat': 0.8573762075992294,
#   'handwriting': 1.2809338454620642,
#   'finale': 1.791759469228055,
#   'presumptive': 8.671115273688493,
#   'william': 1.3016896017385118,
#   'great': 0.0,
#   'grandson': 3.58351893845611,
#   'second': 0.9716930352791265,
#   'vanity': 6.931471805599453,
#   'beginning': 4.740360476642819,
#   'end': 0.0,
#   'character': 19.867790297300054,
#   'person': 3.7690571410042706,
#   'situation': 15.870239952357215,
#   'remarkably': 2.8333848265225545,
#   'youth': 2.734823351909319,
#   'fifty': 3.5267199894127144,
#   'four': 7.159292809561815,
#   'fine': 6.016611374200502,
#   'women': 4.011074249467001,
#   'think': 0.0,
#   'personal': 7.641226643727547,
#   'appearance': 11.819435642347061,
#   'valet': 1.791759469228055,
#   'new': 1.4861187598386643,
#   'made': 0.0,
#   'lord': 1.6408940111455914,
#   'delighted': 7.703837054055123,
#   'place': 0.0,
#   'held': 0.40010889687964035,
#   'society': 6.402194306271325,
#   'considered': 8.460982411300327,
#   'blessing': 4.432288365880148,
#   'beauty': 1.8232155679395459,
#   'inferior': 7.298371945946959,
#   'baronetcy': 5.780743515792329,
#   'united': 2.3511466596084762,
#   'gifts': 0.6931471805599453,
#   'constant': 5.877866649021191,
#   'object': 15.759247523129416,
#   'warmest': 3.0081547935525483,
#   'devotion': 3.0081547935525483,
#   'good': 0.0,
#   'looks': 4.555913606084792,
#   'rank': 3.5796464047809073,
#   'fair': 3.2670875676517803,
#   'claim': 6.238324625039508,
#   'attachment': 32.02334613655161,
#   'since': 2.572128622797688,
#   'must': 0.0,
#   'owed': 5.123735381848257,
#   'superior': 6.238324625039508,
#   'thing': 0.0,
#   'deserved': 6.48744172973063,
#   'excellent': 7.159292809561815,
#   'woman': 3.829613727276558,
#   'sensible': 10.947557918920438,
#   'amiable': 5.676511513514301,
#   'whose': 0.0,
#   'judgement': 12.032619174210193,
#   'conduct': 9.357053216858091,
#   'might': 0.0,
#   'pardoned': 3.295836866004329,
#   'youthful': 0.5877866649021191,
#   'infatuation': 1.5040773967762742,
#   'required': 6.46565331392331,
#   'indulgence': 12.084735175349207,
#   'afterwards': 9.047319418112622,
#   'humoured': 5.666769653045109,
#   'softened': 2.4327906486489863,
#   'concealed': 1.1755733298042381,
#   'failings': 2.1972245773362196,
#   'promoted': 1.5040773967762742,
#   'real': 7.159292809561815,
#   'respectability': 5.493061443340549,
#   'seventeen': 2.8333848265225545,
#   'years': 10.574650294049366,
#   'though': 0.0,
#   'happiest': 4.865581297297973,
#   'world': 0.0,
#   'enough': 4.0582473826363525,
#   'duties': 1.969905940391177,
#   'friends': 1.7147524151984588,
#   'children': 0.0,
#   'attach': 4.394449154672439,
#   'life': 0.0,
#   'make': 0.0,
#   'matter': 1.2003266906389212,
#   'indifference': 6.931471805599453,
#   'called': 5.469646703818638,
#   'quit': 5.290079984119071,
#   'girls': 5.676511513514301,
#   'eldest': 7.053439978825429,
#   'sixteen': 1.888923217681703,
#   'fourteen': 2.8333848265225545,
#   'awful': 1.7633599947063572,
#   'legacy': 1.791759469228055,
#   'mother': 2.4006533812778423,
#   'bequeath': 1.791759469228055,
#   'charge': 0.3646431135879092,
#   'rather': 3.4295048303969176,
#   'confide': 1.2809338454620642,
#   'authority': 2.8382557567571505,
#   'guidance': 4.512232190328822,
#   'conceited': 0.9444616088408515,
#   'silly': 1.969905940391177,
#   'father': 6.687534419273989,
#   'however': 28.962593638681888,
#   'intimate': 8.500154479567664,
#   'friend': 0.0,
#   'deserving': 3.777846435363406,
#   'brought': 0.0,
#   'strong': 3.41570803403512,
#   'settle': 2.277956803042396,
#   'close': 0.0,
#   'village': 4.432288365880148,
#   'kindness': 10.39720770839918,
#   'advice': 1.6271120021731398,
#   'mainly': 1.0986122886681098,
#   'relied': 2.1972245773362196,
#   'best': 0.0,
#   'help': 5.27760299389903,
#   'maintenance': 1.5040773967762742,
#   'principles': 2.4327906486489863,
#   'instruction': 1.0986122886681098,
#   'anxiously': 3.777846435363406,
#   'giving': 4.774974137337217,
#   'daughters': 4.924764850977942,
#   'marry': 12.80438861254265,
#   'whatever': 2.6033792034770236,
#   'anticipated': 2.1972245773362196,
#   'head': 0.0,
#   'acquaintance': 49.46674318919605,
#   'thirteen': 4.1588830833596715,
#   'passed': 13.016896017385118,
#   'away': 0.0,
#   'death': 0.0,
#   'near': 8.204470055727956,
#   'neighbours': 5.676511513514301,
#   'remained': 4.865581297297973,
#   'widower': 3.0081547935525483,
#   'widow': 6.238324625039508,
#   'russell': 325.1892374457605,
#   'steady': 2.8382557567571505,
#   'age': 0.0,
#   'extremely': 12.97488345946126,
#   'well': 0.0,
#   'provided': 1.7633599947063572,
#   'thought': 0.0,
#   'marriage': 10.947557918920438,
#   'needs': 0.9849529701955885,
#   'apology': 3.4657359027997265,
#   'public': 3.939811880782354,
#   'apt': 1.7633599947063572,
#   'unreasonably': 1.5040773967762742,
#   'discontented': 0.9444616088408515,
#   'continuing': 3.4657359027997265,
#   'singleness': 2.1972245773362196,
#   'requires': 2.1972245773362196,
#   'explanation': 2.9548589105867653,
#   'known': 5.771368747162789,
#   'like': 0.0,
#   'met': 0.0,
#   'private': 2.9548589105867653,
#   'disappointments': 3.0081547935525483,
#   'unreasonable': 0.8109302162163288,
#   'applications': 7.16703787691222,
#   'prided': 2.1972245773362196,
#   'remaining': 3.4473353956845596,
#   'single': 1.0939293407637276,
#   'dear': 10.210007180461456,
#   'sake': 4.230491205650163,
#   'would': 0.0,
#   'really': 17.43499964865107,
#   'given': 6.016611374200502,
#   'much': 11.717474837189467,
#   'tempted': 3.243720864865315,
#   'succeeded': 2.4327906486489863,
#   'possible': 2.572128622797688,
#   'rights': 6.931471805599453,
#   'consequence': 10.738939214342722,
#   'influence': 11.755733298042381,
#   'gone': 0.0,
#   'together': 3.0865543473572257,
#   'happily': 3.5267199894127144,
#   'value': 7.703837054055123,
#   'acquired': 5.123735381848257,
#   'little': 0.0,
#   'artificial': 2.3511466596084762,
#   'importance': 7.6246189861593985,
#   'becoming': 2.462382425488971,
#   'mrs': 235.98069291895166,
#   'elegance': 7.690286020676768,
#   'mind': 7.538114282008541,
#   'sweetness': 2.772588722239781,
#   'placed': 3.905068805215535,
#   'people': 2.2291781397579964,
#   'understanding': 11.755733298042381,
#   'nobody': 7.703837054055123,
#   'either': 2.0577028982381504,
#   'sister': 20.607783119034305,
#   'word': 0.0,
#   'weight': 1.3016896017385118,
#   'convenience': 5.493061443340549,
#   'give': 14.403402986722412,
#   'way': 0.0,
#   'indeed': 0.0,
#   'highly': 4.881336006519419,
#   'valued': 4.054651081081644,
#   'god': 1.1778303565638346,
#   'loved': 6.48744172973063,
#   'fancy': 2.277956803042396,
#   'revive': 0.9444616088408515,
#   'pretty': 5.105003590230728,
#   'girl': 3.2542240043462796,
#   'bloom': 4.852030263919617,
#   'vanished': 0.49247648509779424,
#   'early': 6.534175135303561,
#   'even': 17.843324407944337,
#   'height': 0.9762672013038838,
#   'admire': 4.114506654314834,
#   'totally': 6.591673732008658,
#   'different': 6.534175135303561,
#   'delicate': 0.9762672013038838,
#   'features': 8.500154479567664,
#   'mild': 0.5877866649021191,
#   'dark': 1.4585724543516367,
#   'eyes': 0.0,
#   'nothing': 0.0,
#   'faded': 1.4774294552933827,
#   'thin': 0.5026288565618123,
#   'excite': 8.500154479567664,
#   'esteem': 1.4774294552933827,
#   'indulged': 1.2809338454620642,
#   'hope': 3.029395933517277,
#   'none': 0.0,
#   'ever': 14.221081429928459,
#   'reading': 2.0105154262472493,
#   'name': 2.3434949674378935,
#   'work': 1.060047320907451,
#   'equality': 0.6931471805599453,
#   'alliance': 8.958797346140274,
#   'rest': 1.1431682767989724,
#   'merely': 4.054651081081644,
#   'connected': 3.4657359027997265,
#   'old': 0.0,
#   'country': 4.004623212317037,
#   'large': 2.237877677471286,
#   'fortune': 11.758488135136767,
#   'therefore': 1.6004355875185614,
#   'honour': 2.552501795115364,
#   'received': 13.78581367567759,
#   'suitably': 2.8903717578961645,
#   'sometimes': 2.237877677471286,
#   'happens': 1.4774294552933827,
#   'handsomer': 3.58351893845611,
#   'twenty': 2.4734437487840526,
#   'nine': 2.277956803042396,
#   'ten': 1.4133964278766014,
#   'generally': 7.298371945946959,
#   'speaking': 2.4734437487840526,
#   'neither': 1.4289603459987155,
#   'ill': 4.240189283629804,
#   'health': 5.026288565618123,
#   'anxiety': 8.920232378379616,
#   'time': 0.0,
#   'scarcely': 4.460116189189808,
#   'charm': 8.109302162163289,
#   'miss': 40.67780005432849,
#   'begun': 0.6859009660793834,
#   'ago': 4.021030852494499,
#   'excused': 2.8333848265225545,
#   'forgetting': 1.3862943611198906,
#   'least': 2.4006533812778423,
#   'deemed': 2.8333848265225545,
#   'half': 19.525344026077676,
#   'fool': 1.6271120021731398,
#   'thinking': 3.2979249983787366,
#   'blooming': 1.888923217681703,
#   'amidst': 3.295836866004329,
#   'wreck': 1.0986122886681098,
#   'everybody': 8.864576731760296,
#   'else': 0.0,
#   'plainly': 0.4054651081081644,
#   'see': 0.0,
#   'growing': 2.187858681527455,
#   'haggard': 1.791759469228055,
#   'coarse': 0.9849529701955885,
#   'face': 0.0,
#   'neighbourhood': 11.353023027028602,
#   'worsting': 2.8903717578961645,
#   'rapid': 2.3511466596084762,
#   'increase': 2.9389333245105953,
#   'crow': 0.5877866649021191,
#   'foot': 0.0,
#   'temples': 1.888923217681703,
#   'long': 0.0,
#   'distress': 6.0819766216224656,
#   'quite': 6.401742350074246,
#   'equal': 8.920232378379616,
#   'contentment': 0.6931471805599453,
#   'seen': 3.31518800271702,
#   'mistress': 4.114506654314834,
#   'presiding': 3.58351893845611,
#   'directing': 2.1972245773362196,
#   'self': 3.4641095790851373,
#   'possession': 2.6033792034770236,
#   'decision': 2.277956803042396,
#   'idea': 13.016896017385118,
#   'younger': 2.8382557567571505,
#   'honours': 5.676511513514301,
#   'laying': 0.8109302162163288,
#   'law': 2.0105154262472493,
#   'home': 0.0,
#   'leading': 2.027325540540822,
#   'chaise': 7.520386983881371,
#   'walking': 1.2003266906389212,
#   'immediately': 5.287325147024683,
#   'drawing': 4.523659709056311,
#   'rooms': 10.580159968238142,
#   'dining': 3.243720864865315,
#   'winters': 1.0986122886681098,
#   'revolving': 2.5618676909241285,
#   'frosts': 1.791759469228055,
#   'opening': 0.7292862271758184,
#   'ball': 1.2163953243244932,
#   'credit': 4.924764850977942,
#   'scanty': 1.2809338454620642,
#   'afforded': 2.1972245773362196,
#   'springs': 0.8109302162163288,
#   'shewn': 12.032619174210193,
#   'blossoms': 0.4054651081081644,
#   'travelled': 3.4657359027997265,
#   'london': 5.676511513514301,
#   'weeks': 4.924764850977942,
#   'annual': 1.2809338454620642,
#   'enjoyment': 9.010913347279288,
#   'remembrance': 3.5267199894127144,
#   'consciousness': 15.380572041353537,
#   'regrets': 4.512232190328822,
#   'apprehensions': 4.512232190328822,
#   'fully': 5.676511513514301,
#   'satisfied': 5.780231850460842,
#   'felt': 14.585724543516367,
#   'approach': 2.027325540540822,
#   'danger': 1.531179463532985,
#   'rejoiced': 4.054651081081644,
#   'certain': 3.015773139370874,
#   'properly': 5.877866649021191,
#   'solicited': 2.8333848265225545,
#   'blood': 0.4711321426255338,
#   'within': 0.0,
#   'next': 0.0,
#   'twelvemonth': 2.5618676909241285,
#   'take': 0.0,
#   'books': 3.2542240043462796,
#   'liked': 6.0819766216224656,
#   'presented': 1.9525344026077676,
#   'follow': 0.5144257245595376,
#   'youngest': 3.5267199894127144,
#   'evil': 4.555913606084792,
#   'left': 0.0,
#   'open': 1.2003266906389212,
#   'table': 1.766745534845752,
#   'closed': 2.2618298545281554,
#   'averted': 3.58351893845611,
#   'pushed': 0.5877866649021191,
#   'disappointment': 4.394449154672439,
#   'moreover': 4.1588830833596715,
#   'especially': 3.2670875676517803,
#   'present': 7.655897317664925,
#   'generously': 1.791759469228055,
#   'supported': 2.8333848265225545,
#   'disappointed': 3.5267199894127144,
#   'young': 0.0,
#   'soon': 22.243229928862462,
#   'event': 4.7022933192169525,
#   'brother': 3.886840176660654,
#   'future': 5.676511513514301,
#   'meant': 1.8845285705021353,
#   'boy': 0.8002177937592807,
#   'sought': 1.7592009979663432,
#   'overtures': 2.1972245773362196,
#   'warmth': 5.417241336075737,
#   'persevered': 1.5040773967762742,
#   'seeking': 1.4774294552933827,
#   'making': 0.0,
#   'allowance': 2.0794415416798357,
#   'modest': 1.3016896017385118,
#   'back': 0.0,
#   'spring': 1.295613392220218,
#   'excursions': 2.1972245773362196,
#   'mr': 150.47338621494248,
#   'forced': 5.877866649021191,
#   'introduction': 4.865581297297973,
#   'engaged': 6.183025608257931,
#   'study': 0.5026288565618123,
#   'agreeable': 48.67548612755844,
#   'plan': 4.865581297297973,
#   'favour': 8.372100246662502,
#   'confirmed': 1.6218604324326575,
#   'invited': 4.924764850977942,
#   'talked': 15.759247523129416,
#   'expected': 4.523659709056311,
#   'came': 0.0,
#   'following': 4.432288365880148,
#   'town': 4.881336006519419,
#   'equally': 4.432288365880148,
#   'encouraged': 2.772588722239781,
#   'come': 0.0,
#   'tidings': 0.6931471805599453,
#   'instead': 3.7697164242135925,
#   'pushing': 1.888923217681703,
#   'line': 1.4585724543516367,
#   'marked': 1.6218604324326575,
#   'house': 0.0,
#   'purchased': 1.0986122886681098,
# ...
#   'true': 2.743603864317534,
#   'realities': 13.536696570986468,
#   'universes': 23.122974063169316,
#   'purport': 13.536696570986468,
#   'end': 0.0,
#   'permanent': 8.109302162163289,
#   'beyond': 8.569113169315866,
#   'lectures': 3.58351893845611,
#   'learn': 1.371801932158767,
#   'professor': 2.5618676909241285,
#   'telescope': 1.2809338454620642,
#   'spectroscope': 2.8903717578961645,
#   'observer': 1.0986122886681098,
#   'keen': 2.4327906486489863,
#   'mathematics': 1.791759469228055,
#   'doctor': 0.8109302162163288,
#   'surgery': 2.1972245773362196,
#   'anatomy': 2.1972245773362196,
#   'chemist': 11.561487031584658,
#   'chemistry': 9.024464380657644,
#   'entities': 4.394449154672439,
#   'unfix': 2.8903717578961645,
#   'fix': 1.2565721414045308,
#   'shall': 15.032662839906488,
#   'sweeping': 4.054651081081644,
#   'prophet': 3.295836866004329,
#   'bard': 17.91759469228055,
#   'maintain': 3.295836866004329,
#   'stages': 5.375278407684165,
#   'mediate': 2.8903717578961645,
#   'interpret': 0.8109302162163288,
#   'god': 8.83372767422876,
#   'joys': 46.278618833201726,
#   'ceaseless': 16.055847350294474,
#   'exercises': 1.2809338454620642,
#   'exaltations': 5.780743515792329,
#   'yearning': 40.4652046105463,
#   'amply': 1.0986122886681098,
#   'fed': 2.027325540540822,
#   'prepared': 4.881336006519419,
#   'meet': 0.0,
#   'lurking': 3.295836866004329,
#   'within': 0.0,
#   'real': 16.921964822600653,
#   'image': 0.5026288565618123,
#   'special': 6.931471805599453,
#   'strains': 6.404669227310321,
#   'none': 0.0,
#   'resulting': 1.5040773967762742,
#   'rising': 9.047319418112622,
#   'floating': 19.775021196025975,
#   'round': 0.0,
#   'raise': 4.230491205650163,
#   'perennial': 15.380572041353537,
#   'tree': 1.6004355875185614,
#   'roots': 7.879623761564708,
#   'dilate': 14.451858789480823,
#   'fuse': 20.23260230527315,
#   'make': 0.0,
#   'law': 9.047319418112622,
#   'unto': 5.493061443340549,
#   'biography': 2.1972245773362196,
#   'famous': 2.027325540540822,
#   'author': 2.3511466596084762,
#   'calls': 5.877866649021191,
#   'dead': 0.0,
#   'gone': 0.0,
#   'knew': 1.0288514491190752,
#   'aught': 11.528404609158578,
#   'even': 14.324922412011652,
#   'often': 1.4861187598386643,
#   'nothing': 0.0,
#   'hints': 6.48744172973063,
#   'diffused': 7.520386983881371,
#   'clews': 2.1972245773362196,
#   'indirections': 8.788898309344878,
#   'seek': 3.6464311358790917,
#   'trace': 0.9762672013038838,
#   'step': 4.523659709056311,
#   'much': 4.801306762555685,
#   'mere': 5.271046405406137,
#   'fact': 1.0052577131236247,
#   'consciousness': 2.1972245773362196,
#   'forms': 12.163953243244931,
#   'least': 0.7430593799193321,
#   'insect': 3.58351893845611,
#   'animal': 2.0794415416798357,
#   'senses': 2.9288016039116513,
#   'awed': 1.5040773967762742,
#   'hardly': 1.060047320907451,
#   'wish': 0.0,
#   'go': 0.0,
#   'farther': 4.021030852494499,
#   'stop': 1.2574851044788697,
#   'loiter': 11.561487031584658,
#   'beginners': 2.8903717578961645,
#   'provided': 8.229013308629668,
#   'appearing': 4.924764850977942,
#   'intervals': 8.500154479567664,
#   'dreadful': 0.7292862271758184,
#   'inure': 14.33407575382444,
#   'paradox': 3.842801536386193,
#   'people': 2.4578117951177907,
#   'respond': 8.788898309344878,
#   'relentless': 8.788898309344878,
#   'fate': 2.9548589105867653,
#   'times': 0.0,
#   'mischoose': 2.8903717578961645,
#   'adulation': 2.8903717578961645,
#   'reward': 0.4054651081081644,
#   'inexorable': 4.394449154672439,
#   'price': 6.61123126188596,
#   'must': 0.0,
#   'paid': 0.7539432848427186,
#   'purchase': 3.243720864865315,
#   'states': 99.973718268798,
#   'city': 46.785266084290456,
#   'resist': 2.772588722239781,
#   'obey': 2.3511466596084762,
#   'unquestioning': 2.8903717578961645,
#   'obedience': 1.4774294552933827,
#   'fully': 6.48744172973063,
#   'enslaved': 5.375278407684165,
#   'nation': 14.596743891893919,
#   'afterward': 13.183347464017316,
#   'resumes': 3.58351893845611,
#   'liberty': 10.834482672151474,
#   'journeys': 4.722308044204258,
#   'ay': 1.0986122886681098,
#   'urged': 0.9849529701955885,
#   'sailing': 23.070858062030304,
#   'henceforth': 18.80917327686781,
#   'willing': 0.9116077839697729,
#   'learners': 2.8903717578961645,
#   'teachers': 6.016309587105097,
#   'lovers': 37.352817814715735,
#   'watch': 1.5432771736786128,
#   'seasons': 11.333539306090218,
#   'dispensing': 4.394449154672439,
#   'effuse': 17.342230547376985,
#   'dwell': 1.3016896017385118,
#   'town': 2.277956803042396,
#   'pass': 30.660360250270553,
#   'kanada': 26.01334582106548,
#   'north': 19.525344026077676,
#   'east': 6.016611374200502,
#   'valley': 2.3511466596084762,
#   'mississippi': 28.57747053874921,
#   'southern': 15.371206145544772,
#   'confer': 1.791759469228055,
#   'equal': 9.731162594595945,
#   'terms': 5.909717821173531,
#   'trial': 4.432288365880148,
#   'invite': 2.8333848265225545,
#   'men': 0.0,
#   'women': 18.961441906571277,
#   'hear': 16.136275884924533,
#   'remember': 1.1431682767989724,
#   'fear': 0.0,
#   'candid': 2.5618676909241285,
#   'promulge': 5.780743515792329,
#   'copious': 21.972245773362197,
#   'temperate': 1.888923217681703,
#   'chaste': 8.788898309344878,
#   'magnetic': 8.788898309344878,
#   'cantatrice': 2.8903717578961645,
#   'take': 0.0,
#   'gift': 4.7022933192169525,
#   'reserving': 4.512232190328822,
#   'speaker': 0.9444616088408515,
#   'general': 9.325697486487782,
#   'serve': 6.402194306271325,
#   'progress': 4.852030263919617,
#   'freedom': 15.26677103803162,
#   'race': 26.101253710183094,
#   'confronter': 2.8903717578961645,
#   'despots': 5.780743515792329,
#   'daring': 6.46565331392331,
#   'rebel': 2.1972245773362196,
#   'see': 0.0,
#   'belongs': 4.7022933192169525,
#   'imperturbe': 5.780743515792329,
#   'standing': 1.766745534845752,
#   'ease': 2.9288016039116513,
#   'nature': 3.4295048303969176,
#   'master': 2.591226784440436,
#   'mistress': 7.053439978825429,
#   'aplomb': 5.780743515792329,
#   'midst': 4.555913606084792,
#   'irrational': 1.3862943611198906,
#   'things': 4.115405796476301,
#   'imbued': 6.591673732008658,
#   'passive': 2.5618676909241285,
#   'receptive': 6.591673732008658,
#   'silent': 7.891463388977692,
#   'finding': 0.7292862271758184,
#   'occupation': 1.3862943611198906,
#   'poverty': 4.865581297297973,
#   'notoriety': 1.791759469228055,
#   'foibles': 1.5040773967762742,
#   'crimes': 5.493061443340549,
#   'less': 9.298633846393528,
#   'important': 0.7539432848427186,
#   'toward': 57.53121598647546,
#   'mexican': 11.561487031584658,
#   'mannahatta': 46.24594812633863,
#   'tennessee': 16.125835223052494,
#   'inland': 21.972245773362197,
#   'river': 20.191535889009565,
#   'woods': 23.9224413783817,
#   'farm': 12.163953243244931,
#   'coast': 12.476649250079015,
#   'lakes': 28.66815150764888,
#   'wherever': 5.206758406954047,
#   'lived': 4.774974137337217,
#   'balanced': 1.888923217681703,
#   'contingencies': 1.5040773967762742,
#   'confront': 9.024464380657644,
#   'storms': 15.371206145544772,
#   'hunger': 2.4327906486489863,
#   'ridicule': 2.5618676909241285,
#   'accidents': 1.2809338454620642,
#   'rebuffs': 2.8903717578961645,
#   'animals': 20.101268236238415,
#   'savantism': 2.8903717578961645,
#   'thither': 5.417241336075737,
#   'look': 0.0,
#   'result': 2.462382425488971,
#   'glory': 6.0819766216224656,
#   'retracing': 2.1972245773362196,
#   'nestling': 8.788898309344878,
#   'close': 0.0,
#   'always': 13.127152089164731,
#   'obligated': 2.1972245773362196,
#   'hours': 4.881336006519419,
#   'months': 2.8382557567571505,
#   'trades': 5.493061443340549,
#   'compacts': 5.780743515792329,
#   'establishments': 2.8903717578961645,
#   'minute': 3.7697164242135925,
#   'speech': 1.6408940111455914,
#   'utensils': 1.791759469228055,
#   'persons': 11.715206415646605,
#   'estates': 1.791759469228055,
#   'trustful': 5.780743515792329,
#   'admirant': 5.780743515792329,
#   'father': 2.5149702089577395,
#   'going': 0.0,
#   'takes': 1.295613392220218,
#   'children': 0.0,
#   'along': 6.83141606807024,
#   'starting': 8.109302162163289,
#   'unbounded': 1.5040773967762742,
#   'breast': 19.46232518919189,
#   'carrying': 4.881336006519419,
#   'moonsails': 2.8903717578961645,
#   'pennant': 37.352817814715735,
#   'flying': 2.7644587110899677,
#   'aloft': 19.553006158091563,
#   'speeds': 10.986122886681098,
#   'stately': 12.163953243244931,
#   'emulous': 5.375278407684165,
#   'press': 17.328679513998633,
#   'forward': 9.111827212169583,
#   'surround': 13.536696570986468,
#   'shining': 8.109302162163289,
#   'curving': 6.016309587105097,
#   'motions': 3.842801536386193,
#   'singing': 15.07886569685437,
#   'varied': 14.596743891893919,
#   'carols': 31.79408933685781,
#   'mechanics': 26.366694928034633,
#   'blithe': 5.375278407684165,
#   'strong': 10.482690173418128,
#   'carpenter': 3.295836866004329,
#   'measures': 0.8109302162163288,
#   'plank': 7.520386983881371,
#   'beam': 4.722308044204258,
#   'mason': 1.5040773967762742,
#   'makes': 1.4133964278766014,
#   'ready': 0.0,
#   'work': 9.069293745541525,
#   'boatman': 5.780743515792329,
#   'boat': 14.556090791758852,
#   'deckhand': 2.8903717578961645,
#   'steamboat': 6.591673732008658,
#   'shoemaker': 3.58351893845611,
#   'sits': 1.7592009979663432,
#   'bench': 2.0794415416798357,
#   'hatter': 1.791759469228055,
#   'stands': 8.796004989831715,
#   'wood': 1.371801932158767,
#   'cutter': 3.58351893845611,
#   'ploughboy': 2.8903717578961645,
#   'way': 0.0,
#   'morning': 0.0,
#   'noon': 8.109302162163289,
#   'intermission': 0.9444616088408515,
#   'sundown': 23.122974063169316,
#   'delicious': 13.78581367567759,
#   'mother': 5.715841383994862,
#   'wife': 5.287325147024683,
#   'girl': 4.881336006519419,
#   'sewing': 5.375278407684165,
#   'washing': 0.9849529701955885,
#   'else': 0.0,
#   'party': 0.9762672013038838,
#   'fellows': 1.969905940391177,
#   'robust': 10.247470763696514,
#   'friendly': 6.508448008692559,
#   'open': 3.4295048303969176,
#   'mouths': 2.8382557567571505,
#   'melodious': 5.493061443340549,
#   'place': 0.0,
#   'besieged': 3.58351893845611,
#   'vainly': 4.722308044204258,
#   'tries': 1.0986122886681098,
#   'siege': 3.0081547935525483,
#   'commander': 2.1972245773362196,
#   'swift': 9.762672013038838,
#   'horse': 1.060047320907451,
#   'foot': 0.0,
#   'parks': 1.5040773967762742,
#   'artillery': 12.809338454620642,
#   'deadliest': 2.1972245773362196,
#   'fired': 1.888923217681703,
#   'gun': 7.298371945946959,
#   'though': 0.0,
#   'contradictions': 1.791759469228055,
#   'made': 0.0,
#   'dedicate': 8.958797346140274,
#   'nationality': 4.394449154672439,
#   'revolt': 3.842801536386193,
#   'right': 1.7147524151984588,
#   'insurrection': 2.5618676909241285,
#   'quenchless': 4.394449154672439,
#   'indispensable': 2.8333848265225545,
#   'fire': 2.1148613120780992,
#   'shut': 0.40010889687964035,
#   'doors': 6.8338704091271865,
#   'proud': 1.6004355875185614,
#   'libraries': 14.33407575382444,
#   'lacking': 16.125835223052494,
#   'shelves': 1.6218604324326575,
#   'needed': 4.924764850977942,
#   'bring': 4.240189283629804,
#   'emerging': 23.292873099964716,
#   'words': 10.718256244730895,
#   'drift': 13.183347464017316,
#   'thing': 0.0,
#   'link': 3.295836866004329,
#   'felt': 2.3701802383214097,
#   'intellect': 3.777846435363406,
#   'ye': 5.834289817406547,
#   'untold': 19.775021196025975,
#   'latencies': 2.8903717578961645,
#   'thrill': 3.295836866004329,
#   'page': 2.9389333245105953,
#   'orators': 14.451858789480823,
#   'singers': 19.775021196025975,
#   'musicians': 10.75055681536833,
#   'justify': 6.48744172973063,
#   'brood': 12.97488345946126,
#   'native': 8.317766166719343,
#   'continental': 3.842801536386193,
#   'arouse': 14.451858789480823,
#   'two': 0.0,
#   'indicative': 5.780743515792329,
#   'moment': 4.829104461911721,
#   'hurry': 3.243720864865315,
#   'back': 0.0,
#   'darkness': 14.774294552933828,
#   'sauntering': 7.520386983881371,
#   'without': 0.0,
#   'stopping': 3.4473353956845596,
#   'casual': 1.2809338454620642,
#   'averts': 2.8903717578961645,
#   'face': 0.0,
#   'leaving': 6.8338704091271865,
#   'expecting': 0.9444616088408515,
#   'main': 9.010913347279288,
#   'stranger': 2.6033792034770236,
#   'desire': 1.4585724543516367,
#   'speak': 0.0,
#   'reader': 1.888923217681703,
#   'throbbest': 2.8903717578961645,
#   'following': 8.372100246662502,
#   'ii': 0.6508448008692559,
#   'paumanok': 41.74726696938817,
#   'fish': 4.881336006519419,
#   'begotten': 1.5040773967762742,
#   'rais': 19.709354161508603,
#   'roaming': 7.16703787691222,
#   'lover': 19.408121055678468,
#   'populous': 9.887510598012987,
#   'pavements': 15.380572041353537,
#   'dweller': 5.780743515792329,
#   'savannas': 4.394449154672439,
#   'soldier': 6.031546278741748,
#   'camp': 25.618676909241284,
#   'knapsack': 4.394449154672439,
#   'miner': 4.394449154672439,
#   'california': 49.136319884234794,
#   'rude': 5.026288565618123,
#   'home': 0.0,
#   'dakota': 10.986122886681098,
#   'diet': 4.394449154672439,
#   'meat': 5.290079984119071,
#   'drink': 2.7644587110899677,
#   'spring': 3.651274105347887,
#   'withdrawn': 6.61123126188596,
#   'meditate': 2.1972245773362196,
#   'deep': 5.834289817406547,
#   'recess': 1.791759469228055,
#   'clank': 23.122974063169316,
#   'crowds': 19.214007681930962,
#   'happy': 0.0,
#   'aware': 5.290079984119071,
#   'fresh': 1.7719108290384074,
#   'giver': 4.394449154672439,
#   'missouri': 17.91759469228055,
#   'niagara': 15.380572041353537,
#   'buffalo': 5.375278407684165,
#   'herds': 9.024464380657644,
#   'grazing': 4.512232190328822,
#   'plains': 14.166924132612772,
#   'hirsute': 2.8903717578961645,
#   'breasted': 4.394449154672439,
#   'bull': 4.054651081081644,
#   'fifth': 2.772588722239781,
#   'month': 9.849529701955884,
#   'flowers': 3.099466465497228,
#   'experienced': 1.3862943611198906,
#   'rain': 6.508448008692559,
#   'snow': 6.508448008692559,
#   'amaze': 3.842801536386193,
#   'studied': 4.865581297297973,
#   'mocking': 25.56931574519666,
#   'bird': 8.204470055727956,
#   'mountain': 8.372100246662502,
#   'hawk': 8.96653691823445,
#   'dawn': 8.920232378379616,
#   'unrivall': 2.1972245773362196,
#   'hermit': 4.512232190328822,
#   'thrush': 10.986122886681098,
#   'swamp': 10.528541777433919,
#   'cedars': 14.33407575382444,
#   'solitary': 7.879623761564708,
#   'west': 10.574650294049366,
#   'strike': 2.9171449087032735,
#   'union': 12.97488345946126,
#   'identity': 54.93061443340549,
#   'indissoluble': 7.16703787691222,
#   'riches': 9.887510598012987,
#   'kosmos': 17.342230547376985,
#   'reports': 1.6218604324326575,
#   'surface': 10.542092810812274,
#   'throes': 16.125835223052494,
#   'convulsions': 1.5040773967762742,
#   'curious': 13.016896017385118,
#   'underfoot': 6.591673732008658,
#   'overhead': 8.788898309344878,
#   'sun': 6.115950280874503,
#   'globe': 28.382557567571506,
#   'ancestor': 1.2809338454620642,
#   'continents': 23.292873099964716,
#   'away': 0.0,
#   'together': 2.6864454504775854,
#   'south': 14.827551268573464,
#   'isthmus': 3.58351893845611,
#   'trackless': 4.394449154672439,
#   'spaces': 6.016309587105097,
#   'dream': 8.204470055727956,
#   'change': 1.060047320907451,
#   'swiftly': 11.326959157249268,
#   'masses': 16.479184330021646,
#   'debouch': 11.561487031584658,
#   'cover': 18.651394972975563,
#   'foremost': 5.676511513514301,
#   'arts': 10.542092810812274,
#   'institutions': 14.451858789480823,
#   'projected': 3.295836866004329,
#   'audience': 3.4657359027997265,
#   'interminable': 18.04892876131529,
#   'regular': 1.4774294552933827,
#   'wend': 8.671115273688493,
#   'never': 24.248767053595962,
#   'successions': 11.561487031584658,
#   'americanos': 8.671115273688493,
#   'hundred': 4.774974137337217,
#   'millions': 13.78581367567759,
#   'generation': 4.394449154672439,
#   'playing': 3.2542240043462796,
#   'part': 0.0,
#   'another': 0.0,
#   'turn': 0.0,
#   'faces': 0.0,
#   'sideways': 6.016309587105097,
#   'backward': 4.852030263919617,
#   'towards': 1.060047320907451,
#   'listen': 2.4734437487840526,
#   'retrospective': 17.342230547376985,
#   'marches': 24.169470350698415,
#   'humanitarian': 2.1972245773362196,
#   'century': 5.666769653045109,
#   'libertad': 52.02669164213096,
#   'programme': 5.375278407684165,
#   'prairies': 37.60193491940685,
#   'running': 5.528917422179935,
#   'ohio': 23.292873099964716,
#   'indiana': 13.183347464017316,
#   'illinois': 12.542316284596385,
#   'iowa': 6.591673732008658,
#   'wisconsin': 6.591673732008658,
#   'minnesota': 5.780743515792329,
#   'kansas': 10.986122886681098,
#   'equidistant': 2.8903717578961645,
#   'shooting': 3.4657359027997265,
#   ...}}

# %% [markdown]
# ### Exercise 2.3
# * Recompute the average similarity between the collection of books (as in Ex 1.3).
# * What do you notice?

# %%
tfidf_books=convert_to_tfidf(book_reps,books_idf)
average_similarity(tfidf_books,tfidf_books)
# Out:
# Types of documents: <class 'dict'> <class 'dict'>
# 0.08605545518027201

# %% [markdown]
# Using tfidf values as weight, average similarity is a lot lower.  This is presumably because of less accidental overlap of commonly occurring words.

# %% [markdown]
# ### Exercise 2.4
# For each book in the collection, find it's most similar book (NOT INCLUDING ITSELF!).
# Output your results in a table

# %%
allsims=all_pairs_sims(tfidf_books,tfidf_books)
# Out:
# Types of documents: <class 'dict'> <class 'dict'>

# %%
df=pd.DataFrame(allsims)
df
# Out:
#                          austen-emma.txt  austen-persuasion.txt  \
# austen-emma.txt                 1.000000               0.065044
# austen-persuasion.txt           0.065044               1.000000
# austen-sense.txt                0.048227               0.050586
# bible-kjv.txt                   0.005446               0.007797
# blake-poems.txt                 0.006677               0.009049
# bryant-stories.txt              0.014007               0.023258
# burgess-busterbrown.txt         0.005947               0.005254
# carroll-alice.txt               0.004657               0.006090
# chesterton-ball.txt             0.010096               0.010527
# chesterton-brown.txt            0.038462               0.043906
# chesterton-thursday.txt         0.007343               0.008855
# edgeworth-parents.txt           0.076654               0.097921
# melville-moby_dick.txt          0.013983               0.029459
# milton-paradise.txt             0.016060               0.020528
# shakespeare-caesar.txt          0.000819               0.001015
# shakespeare-hamlet.txt          0.001688               0.002234
# shakespeare-macbeth.txt         0.001382               0.001829
# whitman-leaves.txt              0.017726               0.026094
#
#                          austen-sense.txt  bible-kjv.txt  blake-poems.txt  \
# austen-emma.txt                  0.048227       0.005446         0.006677
# austen-persuasion.txt            0.050586       0.007797         0.009049
# austen-sense.txt                 1.000000       0.006294         0.007058
# bible-kjv.txt                    0.006294       1.000000         0.083024
# blake-poems.txt                  0.007058       0.083024         1.000000
# bryant-stories.txt               0.013670       0.069120         0.044000
# burgess-busterbrown.txt          0.003219       0.002086         0.008476
# carroll-alice.txt                0.004582       0.003607         0.006896
# chesterton-ball.txt              0.006609       0.007410         0.009194
# chesterton-brown.txt             0.026448       0.021546         0.022680
# chesterton-thursday.txt          0.007644       0.007278         0.009401
# edgeworth-parents.txt            0.098512       0.019879         0.031436
# melville-moby_dick.txt           0.012348       0.042034         0.035741
# milton-paradise.txt              0.017807       0.201482         0.212993
# shakespeare-caesar.txt           0.000914       0.020034         0.016799
# shakespeare-hamlet.txt           0.002165       0.033457         0.021174
# shakespeare-macbeth.txt          0.001689       0.027459         0.022125
# whitman-leaves.txt               0.017874       0.102387         0.141815
#
#                          bryant-stories.txt  burgess-busterbrown.txt  \
# austen-emma.txt                    0.014007                 0.005947
# austen-persuasion.txt              0.023258                 0.005254
# austen-sense.txt                   0.013670                 0.003219
# bible-kjv.txt                      0.069120                 0.002086
# blake-poems.txt                    0.044000                 0.008476
# bryant-stories.txt                 1.000000                 0.027962
# burgess-busterbrown.txt            0.027962                 1.000000
# carroll-alice.txt                  0.021555                 0.006396
# chesterton-ball.txt                0.017104                 0.004665
# chesterton-brown.txt               0.054973                 0.018464
# chesterton-thursday.txt            0.014750                 0.003558
# edgeworth-parents.txt              0.055212                 0.014187
# melville-moby_dick.txt             0.051922                 0.006509
# milton-paradise.txt                0.056770                 0.005224
# shakespeare-caesar.txt             0.003751                 0.000284
# shakespeare-hamlet.txt             0.009235                 0.000596
# shakespeare-macbeth.txt            0.006737                 0.000530
# whitman-leaves.txt                 0.078491                 0.015114
#
#                          carroll-alice.txt  chesterton-ball.txt  \
# austen-emma.txt                   0.004657             0.010096
# austen-persuasion.txt             0.006090             0.010527
# austen-sense.txt                  0.004582             0.006609
# bible-kjv.txt                     0.003607             0.007410
# blake-poems.txt                   0.006896             0.009194
# bryant-stories.txt                0.021555             0.017104
# burgess-busterbrown.txt           0.006396             0.004665
# carroll-alice.txt                 1.000000             0.005226
# chesterton-ball.txt               0.005226             1.000000
# chesterton-brown.txt              0.016924             0.041285
# chesterton-thursday.txt           0.005901             0.018068
# edgeworth-parents.txt             0.015762             0.017852
# melville-moby_dick.txt            0.009133             0.017743
# milton-paradise.txt               0.009493             0.024758
# shakespeare-caesar.txt            0.000525             0.001024
# shakespeare-hamlet.txt            0.001804             0.002162
# shakespeare-macbeth.txt           0.001075             0.001458
# whitman-leaves.txt                0.013503             0.033770
#
#                          chesterton-brown.txt  chesterton-thursday.txt  \
# austen-emma.txt                      0.038462                 0.007343
# austen-persuasion.txt                0.043906                 0.008855
# austen-sense.txt                     0.026448                 0.007644
# bible-kjv.txt                        0.021546                 0.007278
# blake-poems.txt                      0.022680                 0.009401
# bryant-stories.txt                   0.054973                 0.014750
# burgess-busterbrown.txt              0.018464                 0.003558
# carroll-alice.txt                    0.016924                 0.005901
# chesterton-ball.txt                  0.041285                 0.018068
# chesterton-brown.txt                 1.000000                 0.041208
# chesterton-thursday.txt              0.041208                 1.000000
# edgeworth-parents.txt                0.068564                 0.016128
# melville-moby_dick.txt               0.051170                 0.015510
# milton-paradise.txt                  0.049645                 0.019804
# shakespeare-caesar.txt               0.004398                 0.001097
# shakespeare-hamlet.txt               0.006621                 0.001798
# shakespeare-macbeth.txt              0.004456                 0.001229
# whitman-leaves.txt                   0.083248                 0.029950
#
#                          edgeworth-parents.txt  melville-moby_dick.txt  \
# austen-emma.txt                       0.076654                0.013983
# austen-persuasion.txt                 0.097921                0.029459
# austen-sense.txt                      0.098512                0.012348
# bible-kjv.txt                         0.019879                0.042034
# blake-poems.txt                       0.031436                0.035741
# bryant-stories.txt                    0.055212                0.051922
# burgess-busterbrown.txt               0.014187                0.006509
# carroll-alice.txt                     0.015762                0.009133
# chesterton-ball.txt                   0.017852                0.017743
# chesterton-brown.txt                  0.068564                0.051170
# chesterton-thursday.txt               0.016128                0.015510
# edgeworth-parents.txt                 1.000000                0.036234
# melville-moby_dick.txt                0.036234                1.000000
# milton-paradise.txt                   0.037563                0.086169
# shakespeare-caesar.txt                0.003280                0.006841
# shakespeare-hamlet.txt                0.008625                0.010547
# shakespeare-macbeth.txt               0.005294                0.007338
# whitman-leaves.txt                    0.048973                0.127190
#
#                          milton-paradise.txt  shakespeare-caesar.txt  \
# austen-emma.txt                     0.016060                0.000819
# austen-persuasion.txt               0.020528                0.001015
# austen-sense.txt                    0.017807                0.000914
# bible-kjv.txt                       0.201482                0.020034
# blake-poems.txt                     0.212993                0.016799
# bryant-stories.txt                  0.056770                0.003751
# burgess-busterbrown.txt             0.005224                0.000284
# carroll-alice.txt                   0.009493                0.000525
# chesterton-ball.txt                 0.024758                0.001024
# chesterton-brown.txt                0.049645                0.004398
# chesterton-thursday.txt             0.019804                0.001097
# edgeworth-parents.txt               0.037563                0.003280
# melville-moby_dick.txt              0.086169                0.006841
# milton-paradise.txt                 1.000000                0.035504
# shakespeare-caesar.txt              0.035504                1.000000
# shakespeare-hamlet.txt              0.063255                0.270705
# shakespeare-macbeth.txt             0.064595                0.230586
# whitman-leaves.txt                  0.263106                0.016665
#
#                          shakespeare-hamlet.txt  shakespeare-macbeth.txt  \
# austen-emma.txt                        0.001688                 0.001382
# austen-persuasion.txt                  0.002234                 0.001829
# austen-sense.txt                       0.002165                 0.001689
# bible-kjv.txt                          0.033457                 0.027459
# blake-poems.txt                        0.021174                 0.022125
# bryant-stories.txt                     0.009235                 0.006737
# burgess-busterbrown.txt                0.000596                 0.000530
# carroll-alice.txt                      0.001804                 0.001075
# chesterton-ball.txt                    0.002162                 0.001458
# chesterton-brown.txt                   0.006621                 0.004456
# chesterton-thursday.txt                0.001798                 0.001229
# edgeworth-parents.txt                  0.008625                 0.005294
# melville-moby_dick.txt                 0.010547                 0.007338
# milton-paradise.txt                    0.063255                 0.064595
# shakespeare-caesar.txt                 0.270705                 0.230586
# shakespeare-hamlet.txt                 1.000000                 0.335677
# shakespeare-macbeth.txt                0.335677                 1.000000
# whitman-leaves.txt                     0.024463                 0.023106
#
#                          whitman-leaves.txt
# austen-emma.txt                    0.017726
# austen-persuasion.txt              0.026094
# austen-sense.txt                   0.017874
# bible-kjv.txt                      0.102387
# blake-poems.txt                    0.141815
# bryant-stories.txt                 0.078491
# burgess-busterbrown.txt            0.015114
# carroll-alice.txt                  0.013503
# chesterton-ball.txt                0.033770
# chesterton-brown.txt               0.083248
# chesterton-thursday.txt            0.029950
# edgeworth-parents.txt              0.048973
# melville-moby_dick.txt             0.127190
# milton-paradise.txt                0.263106
# shakespeare-caesar.txt             0.016665
# shakespeare-hamlet.txt             0.024463
# shakespeare-macbeth.txt            0.023106
# whitman-leaves.txt                 1.000000

# %%
from operator import itemgetter
import pandas as pd

def nearestneighbours(simmatrix):
    nn={}

    for bookid,simdict in simmatrix.items():
        ordered=sorted(simdict.items(),key=itemgetter(1),reverse=True)
        nn[bookid]=ordered[1]
    return nn
        

print( f'\n---------------------------------------------------\n' )

nn1=nearestneighbours(allsims)
df = pd.DataFrame(nn1)
df=df.transpose()
df.columns=['nearest neighbour','similarity']
df
# Out:
# ---------------------------------------------------
#                                nearest neighbour similarity
# austen-emma.txt            edgeworth-parents.txt   0.076654
# austen-persuasion.txt      edgeworth-parents.txt   0.097921
# austen-sense.txt           edgeworth-parents.txt   0.098512
# bible-kjv.txt                milton-paradise.txt   0.201482
# blake-poems.txt              milton-paradise.txt   0.212993
# bryant-stories.txt            whitman-leaves.txt   0.078491
# burgess-busterbrown.txt       bryant-stories.txt   0.027962
# carroll-alice.txt             bryant-stories.txt   0.021555
# chesterton-ball.txt         chesterton-brown.txt   0.041285
# chesterton-brown.txt          whitman-leaves.txt   0.083248
# chesterton-thursday.txt     chesterton-brown.txt   0.041208
# edgeworth-parents.txt           austen-sense.txt   0.098512
# melville-moby_dick.txt        whitman-leaves.txt    0.12719
# milton-paradise.txt           whitman-leaves.txt   0.263106
# shakespeare-caesar.txt    shakespeare-hamlet.txt   0.270705
# shakespeare-hamlet.txt   shakespeare-macbeth.txt   0.335677
# shakespeare-macbeth.txt   shakespeare-hamlet.txt   0.335677
# whitman-leaves.txt           milton-paradise.txt   0.263106
